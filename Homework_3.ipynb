# %% [markdown]
# # STEP 1 : Data
#
# We have donwloaded the data. It is saved in Airbnb_Texas_Rentals.csv. You can find the in the root of repository.

# %% [markdown]
# # Step 2 : Create documents
#
# For creating the documents I have used function named as *create_tsv_files* in the writing_of_data.py file. We will write all the steps one by one and will run the script here.

# %%
def create_tsv_files(df, folder_name):  # this function will be used to crete tsv files
    # Create a tsv file for each row
    pathlib.Path(folder_name).mkdir(parents=True, exist_ok=True)  # create a doc folder first
    for i in range(len(df)):
        pd.DataFrame(df.iloc[i]).transpose().to_csv(folder_name + '/doc_%s.tsv' % i, sep='\t')

# %% [markdown]
# # Step 3: Search Engine

# %% [markdown]
# We have used nltk library for removing stopwords, punctuation, Stemming, //n values and integers. We have also removed the null values in title and description. All of this code you will find inside the cleaning_of_data.py. For convenience We are going to add functions of cleaning of data here.
#
# 1. Function open_csv_file_and_remove_extra_values(filename) will be used to clean the title and description and will return the dataframe.
# 2. Function remove_extras_from_query(query) will get the sentence or query. It can be paragraph or simple line or query it does not matter at the end it will return list of words back to the user.

# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import RegexpTokenizer

def open_csv_file_and_remove_extra_values(filename):  # open csv file and clean the data

    # Import the data
    df = pd.read_csv(filename)
    df.isnull().sum()
    # Drop the rows with null numbers
    df = df[pd.notnull(df["description"])]
    df = df[pd.notnull(df["title"])]
    return df


def remove_extras_from_query(query):  # use all the techniques to remove unwanted items from words

    tokenizer = RegexpTokenizer(r'\w+')

    ps = PorterStemmer()
    # Remove "\\n" and replace with a space
    words = query.replace("\\n", " ")
    # Convert everything to lowercase
    words = words.lower()
    # Removing punctuation
    words = tokenizer.tokenize(words)
    # Stemming
    words = [ps.stem(word) for word in words]
    # Removing stopwords
    words = [word for word in words if word not in stopwords.words('english')]
    # No integers
    words = [x for x in words if not (x.isdigit() or x[0].isdigit())]

    return words

# %% [markdown]
# ## 3.1) Conjunctive query

# %% [markdown]
# ### 3.1.1) Create your index!

# %% [markdown]
# Lets see the script of search_engine.py in action. We will be using it for the whole assignment and we will be updating it step by step.
#
# 1. Lets take a look at the script which will be using cleaning of the data by using nltk library.
# 2. After that it will create a vocabulary file.
# 3. After that it will create the inverted index file.
# 4. Names of the files will be at the top of the script so that it can change later easily.

# %%
import cleaning_of_data  
import writing_of_data
import reading_of_data
import search_engine_processing

# %%
CSV_FILE_NAME = "Airbnb_Texas_Rentals.csv"  # constant csv file name
FOLDER_NAME_FOR_TSV_File = "doc_files" # this will be used to create doc_files folder for tsv files. 
VOC_FILE_NAME = "vocabulary.json" # this will be vocabulary file for our search engine
INVERTED_INDEX_FILE_NAME = "inverted_index.json" # this will be inverted index file name

# cleaning of data
df = cleaning_of_data.open_csv_file_and_remove_extra_values(CSV_FILE_NAME)

# %%
writing_of_data.create_tsv_files(df, FOLDER_NAME_FOR_TSV_File) # creating tsv files inside doc_files folder

# %% [markdown]
# Above script created all the tsv files after reading it from the CSV file.

# %% [markdown]
# 1. Before creating inverted index file we have to create dictionary file which will contains all the words that are inside the csv file. For that I will be using the writing_of_data.py file which will will have the function named as create_vocabulary_file() function to create the vocabulary file. First argument will get the length of the dataframe so that it will get all the documents. Also. it will get folder name as second argument for TSV file for reading each document one by one. Also it will get vocabulary name as third argument.
# 2. After that we will create inverted index file which will get the inverted index file name as third argumument other are the same for vocabulary function.
#
# Below are the definition of the functions. I have added comments so that they explain theirselves.

# %%
def create_vocabulary_file(df_length, folder_name, voc_file_name):
    # Create an empty set for the vocabulary
    voc_set = set()

    # For every file...
    for i in range(df_length):
        doc = pd.read_csv(folder_name + '/doc_%s.tsv' % i, sep='\t')
        print("creating vocabulary ed index:" + str(i))
        # Concatenate the description and title in a string
        words = doc["description"][0] + doc["title"][0]

        words = cleaning_of_data.remove_extras_from_query(words)

        # Storage the words in vocabulary set
        voc_set.update(words)

    # As a result of this problem, we have a vocabulary set with unique words
    # an a dictionary, with key: number of the document values: a list of all the words (filtered) in the Airbnb post

    # Create a vocabulary dictionary from the set dictionary
    voc_dict = {}
    voc_list = list(voc_set)
    for i in range(len(voc_list)):
        voc_dict[i] = voc_list[i]

    # saving it to Json file
    with open(voc_file_name, 'w') as fp:
        json.dump(voc_dict, fp, sort_keys=True, indent=4)

    return voc_dict

def create_inverted_index_file(df_length, folder_name, dic_file_name):
    # And an empty dictionary for storage the words for each document
    dictionary = {}

    # For every file...
    for i in range(df_length):
        doc = pd.read_csv(folder_name + '/doc_%s.tsv' % i, sep='\t')
        print("creating inverted index:" + str(i))

        # Concatenate the description and title in a string
        words = doc["description"][0] + doc["title"][0]

        words = cleaning_of_data.remove_extras_from_query(words)

        # Storage the words in vocabulary set
        dictionary.update({i: words})

    # As a result of this problem, we have a vocabulary set with unique words
    # an a dictionary, with key: number of the document values: a list of all the words (filtered) in the Airbnb post

    # Create the index
    inverted_index = defaultdict(str)

    for key, value in dictionary.items():

        list_of_words = list(value)
        voc_dic = reading_of_data.get_vocabulary_dic()  # get a dictionary from dictionary file
        for value in list_of_words:
            # get term id from voc_dic
            term_id = list(voc_dic.keys())[list(voc_dic.values()).index(value)]
            if str(term_id) in inverted_index:

                inverted_index[str(term_id)].append(key)
            else:
                inverted_index[str(term_id)] = [key]

    # saving it to Json file
    with open(dic_file_name, 'w') as fp:
        json.dump(inverted_index, fp, sort_keys=True, indent=4)

    return inverted_index

# %% [markdown]
# To run above functions we will calling above functions one by one for creating vocabulary file and inverted index file.

# %%
# These methods are used to create vocabulary and dictionary files.
writing_of_data.create_vocabulary_file(len(df), FOLDER_NAME_FOR_TSV_File, VOC_FILE_NAME)
writing_of_data.create_inverted_index_file(len(df), FOLDER_NAME_FOR_TSV_File, INVERTED_INDEX_FILE_NAME)

# %% [markdown]
# After above functions run we will have vocabulary and inverted index file in the root[Main Directory] our repository named as **vocabulary.json** and **inverted_index.json**

# %% [markdown]
# ### 3.1.2) Execute the query
#
# Now that we have **vocabulary.json** file and **inverted_index.json**. We can do do the first part of our seach engine. Which is getting the document using And query containing all the words.
#
# I have also created another function in **reading_of_data.py** file named as **get_inverted_index_file** which will get the content of the **inverted_index_file.json** file and assign it to **inverted_index_dic** object. Let me write its definition here

# %%
def get_inverted_index_file(file_name='inverted_index.json"'):  # reading inverted_index dictionary file

    # Create an empty set for the vocabulary
    with open(file_name, 'r') as fp:
        data = json.load(fp)
    return data

# %% [markdown]
# After that I will get the input from the user and clean the query as I did before. Let me write those lines here.

# %%
# # Now we have our inverted_index_file
inverted_index_dic = reading_of_data.get_inverted_index_file(INVERTED_INDEX_FILE_NAME)
query = input()
words = cleaning_of_data.remove_extras_from_query(query)
# Out:
# Book Your Group at One Location and Save!!\nVideo Tour Available Upon Request

# %% [markdown]
# Now inverted_index_dic will have all the inverted_index_dictionary items in **inverted_index_dic** object and **words**  will have the dictionary list of each word in the query. Just run it.

# %%
words
# Out:
# ['book',
#  'group',
#  'one',
#  'locat',
#  'save',
#  'video',
#  'tour',
#  'avail',
#  'upon',
#  'request']

# %% [markdown]
# We will also use two more functions which are **run_simple_conjunctive_query** inside the **search_engine_processing.py** file and **output_results** which is inside the **writing_of_data.py** file. Let me post both definition here.

# %%
def run_simple_conjunctive_query(words, inverted_index_items):
    query = list(words)

    # Each of the querys matches should contain all the words on the list query
    voc_dic = reading_of_data.get_vocabulary_dic()  # get a dictionary from dictionary file
    querys_matches = []
    for word in query:
        term_id = list(voc_dic.keys())[list(voc_dic.values()).index(word)]
        if term_id in inverted_index_items.keys():
            querys_matches.append(set(inverted_index_items[term_id]))
    # As a result we are going to have a list, with all the matches, called inter
    k = 0
    if len(querys_matches) > 0:
        inter = querys_matches[k]
        k += 1
        for i in range(1, len(querys_matches)):
            inter = inter.intersection(querys_matches[k])
            k += 1
    return inter

def output_results(folder_name, inter):
    if inter == set():
        print("No results were found with those characteristics")
        return
    else:
        index = 0
        inter = list(inter)
        cols_of_interest = ["Title", "Description", "City", "Url"]
        if len(inter) > 0:
            doc_id = inter[0]
            df = pd.read_csv(folder_name + "/doc_%s.tsv" % doc_id, sep="\t")
            df = df.rename(index=str,
                           columns={'title': 'Title',
                                    "description": "Description", "city": "City", "url": 'Url'})
            df = df.filter(cols_of_interest, axis=1)
        index += 1
        for i in range(1, len(inter)):
            doc_id = int(inter[i])
            cols_of_interest = ["Title", "Description", "City", "Url"]
            file = pd.read_csv(folder_name + "/doc_%s.tsv" % doc_id, sep="\t")
            file = file.rename(index=str, columns={'title': 'Title',
                                                   "description": "Description", "city": "City", "url": 'Url'})
            df = df.append(file.filter(cols_of_interest, axis=1), ignore_index=True, sort=False)

    df.reset_index(drop=True, inplace=True)
    print(df.to_string())
    return df

# %%
result_items = search_engine_processing.run_simple_conjunctive_query(words, inverted_index_dic)
df = writing_of_data.output_results(FOLDER_NAME_FOR_TSV_File, result_items)

# %% [markdown]
# **result_items** will contain the name of the document and **df** will have the all the dataframe rows after simple query

# %%
result_items
# Out:
# {4403, 16387, 17534}

# %%
df
# Out:
#                                Title  \
# 0  Quiet Getaway Near I-35/UNT/TWU!!
# 1  Quiet Getaway Near I-35/UNT/TWU!!
# 2  Quiet Getaway Near I-35/UNT/TWU!!
#
#                                          Description    City  \
# 0  Book Your Group at One Location and Save!!\nVi...  Denton
# 1  Book Your Group at One Location and Save!!\nVi...  Denton
# 2  Book Your Group at One Location and Save!!\nVi...  Denton
#
#                                                  Url
# 0  https://www.airbnb.com/rooms/15609235?location...
# 1  https://www.airbnb.com/rooms/15609235?location...
# 2  https://www.airbnb.com/rooms/15609235?location...

# %% [markdown]
# **As from above you can clearly see the And result. Notice it looks like they are same dataframe but they are not to clearify this I have to display urls.**

# %%
list(df["Url"])
# Out:
# ['https://www.airbnb.com/rooms/15609235?location=Aubrey%2C%20TX',
#  'https://www.airbnb.com/rooms/15609235?location=Corinth%2C%20TX',
#  'https://www.airbnb.com/rooms/15609235?location=Argyle%2C%20TX']

# %% [markdown]
# Now you you can see that all the urls are different. Lets move to 3.2 section of working on
# **3.2) Conjunctive query & Ranking score**

# %% [markdown]
# ### 3.2) Conjunctive query & Ranking score
# 1. Find all the documents that contains all the words in the query (as before...).
# 2. Sort them by their similarity with the query
# 3. Return in output k documents, or all the documents with non-zero similarity with the query when the results are less than k. You must use a heap data structure (you can use Python libraries) for maintaining the top-k documents.

# %% [markdown]
# To create a search engine which will fulfill above requirements we have to create new inverted index file as rquired to show **Term Frequency – Inverse Document Frequency** for each word in the document. Also we have to calculate Cosine Similarity for each document. We have used this url to understand how TFIDF works and what is cosine similarity
# https://janav.wordpress.com/2013/10/27/tf-idf-and-cosine-similarity/
#
# After that I have created **inverted_index_tfidf.json** using below function. But in the script it resides in **writing_of_data.py** file.

# %%
def create_tfidf_inverted_index_file(df_length, folder_name, dic_file_name):
    # And an empty dictionary for storage the words for each document

    dictionary = {}
    dictionary_items = []
    # For every file...
    for i in range(df_length):
        doc = pd.read_csv(folder_name + '/doc_%s.tsv' % i, sep='\t')
        print("creating inverted index tfidf:" + str(i))

        # Concatenate the description and title in a string
        words = doc["description"][0] + doc["title"][0]

        words = cleaning_of_data.remove_extras_from_query(words)

        # Storage the words in vocabulary set
        dictionary.update({i: words})
        dictionary_items.append(" ".join(list(words)))

    # As a result of this problem, we have a vocabulary set with unique words
    # an a dictionary, with key: number of the document values: a list of all the words (filtered) in the Airbnb post

    # Create the index
    inverted_index = defaultdict(str)
    voc_long_string = reading_of_data.get_vocabulary_dic()
    voc_dic = reading_of_data.get_vocabulary_dic()
    file_items = " ".join(dictionary_items)
    tfidf = TfidfVectorizer(input=file_items, sublinear_tf=True)
    response = tfidf.fit_transform(dictionary_items)

    feature_names = tfidf.get_feature_names()

    for key, value in dictionary.items():
        print(" ---------- Document %s ------- " % key)
        feature_index = response[key, :].nonzero()[1]
        tfidf_scores = zip(feature_index, [response[key, x] for x in feature_index])
        for w, s in [(feature_names[i], s) for (i, s) in tfidf_scores]:
            term_id = list(voc_dic.keys())[list(voc_dic.values()).index(w)]
            if str(term_id) in inverted_index:
                inverted_index[str(term_id)].append({key: s})
            else:
                inverted_index[str(term_id)] = [{key: s}]
    # saving it to Json file
    with open(dic_file_name, 'w') as fp:
        json.dump(inverted_index, fp, sort_keys=True, indent=4)

    return inverted_index

# %% [markdown]
# For this We have used **sklearn** library and used particular namespace **TfidfVectorizer**. To use this correctly I have used https://github.com/mayank408/TFIDF/blob/master/Sklearn%20TFIDF.ipynb file as helper file. After that I know how it all works and I just continued on creating inverted_index_tfidf.json file. Lets run the function to see it in action.

# %%
INVERTED_INDEX_TFIDF_FILE_NAME = "inverted_index_tfidf.json"

# %%
df = cleaning_of_data.open_csv_file_and_remove_extra_values(CSV_FILE_NAME)
writing_of_data.create_tfidf_inverted_index_file(len(df), FOLDER_NAME_FOR_TSV_File, INVERTED_INDEX_TFIDF_FILE_NAME)

# %% [markdown]
# Now above lines will create inverted index file with **tfidf** values. So to read the file we have to create function which will read the tfidf into dictionary object. For this we have created this function named as **get_tfidf_inverted_index_file** resides in **reading_of_data.py** file. Let me write the function here.

# %%
def get_tfidf_inverted_index_file(file_name='inverted_index_tfidf.json"'):  # reading tfidf inverted_index dictionary file

    # Create an empty set for the vocabulary
    with open(file_name, 'r') as fp:
        data = json.load(fp)
    return data

# %% [markdown]
# After this we have to just call this function

# %%
inverted_index_dic = reading_of_data.get_tfidf_inverted_index_file(INVERTED_INDEX_TFIDF_FILE_NAME)

# %%
list(inverted_index_dic.items())[:2] # only two elements of inverted_index_dic
# Out:
# [('0', [{'1295': 0.3509427613911738}, {'15637': 0.5332534879691798}]),
#  ('1',
#   [{'33': 0.1668036991306726},
#    {'42': 0.16853470157221048},
#    {'68': 0.14250562593787316},
#    {'77': 0.11374958724854627},
#    {'98': 0.15002300650162795},
#    {'138': 0.12824742576530407},
#    {'232': 0.21031274165339703},
#    {'234': 0.14246618989808812},
#    {'235': 0.15019778013159235},
#    {'287': 0.1207427602764078},
#    {'309': 0.15228377972706172},
#    {'317': 0.11207830683128686},
#    {'327': 0.11082854898215158},
#    {'360': 0.1286249832680968},
#    {'363': 0.1702486806765383},
#    {'374': 0.11273402296785252},
#    {'426': 0.08645262523959589},
#    {'445': 0.1367980077213027},
#    {'459': 0.13691046155949088},
#    {'461': 0.1748327559541605},
#    {'500': 0.08695823736935757},
#    {'534': 0.13730867748127507},
#    {'545': 0.11793029673329705},
#    {'563': 0.1482906348209445},
#    {'589': 0.12148656843918638},
#    {'609': 0.11896540969742374},
#    {'648': 0.1423695184419867},
#    {'664': 0.11995307795414739},
#    {'688': 0.16869350056471769},
#    {'699': 0.1452842346731077},
#    {'732': 0.1302717309139074},
#    {'852': 0.17750157971698885},
#    {'854': 0.12997686453428287},
#    {'892': 0.13902824735210356},
#    {'898': 0.1702486806765383},
#    {'908': 0.113926628273744},
#    {'917': 0.1724395891429554},
#    {'926': 0.0999756254965862},
#    {'933': 0.12636762221375444},
#    {'957': 0.1499239827712403},
#    {'971': 0.14215902266167246},
#    {'1012': 0.18080763971974137},
#    {'1036': 0.16389574955006678},
#    {'1052': 0.11108082103728655},
#    {'1087': 0.17781372047770255},
#    {'1150': 0.11793029673329705},
#    {'1165': 0.12794854874580083},
#    {'1212': 0.15113086933161535},
#    {'1233': 0.17425340836218947},
#    {'1242': 0.11854679694328797},
#    {'1257': 0.1466708136341621},
#    {'1377': 0.16961673101400382},
#    {'1393': 0.13730867748127507},
#    {'1406': 0.11814594580087602},
#    {'1408': 0.2270540961471652},
#    {'1432': 0.13119548657104776},
#    {'15913': 0.11588318502878821},
#    {'15922': 0.13965574046194804},
#    {'15961': 0.11512814301044481},
#    {'16006': 0.13691046155949088},
#    {'16012': 0.11911932896048644},
#    {'16034': 0.10842568662299745},
#    {'16040': 0.15019778013159235},
#    {'16139': 0.1204732236889132},
#    {'16145': 0.15682800258218882},
#    {'16166': 0.13860564757673213},
#    {'16176': 0.16859907625022777},
#    {'16200': 0.11084932197290805},
#    {'16221': 0.0969166009271465},
#    {'16222': 0.25564757237159746},
#    {'16239': 0.15980740437679208},
#    {'16268': 0.0999756254965862},
#    {'16281': 0.14866080544564422},
#    {'16299': 0.11469647605506061},
#    {'16309': 0.24589628203577021},
#    {'16313': 0.15048871837406488},
#    {'16322': 0.11606550906033888},
#    {'16334': 0.20446644240588716},
#    {'16368': 0.29764137594012235},
#    {'16448': 0.13780460270197942},
#    {'16505': 0.12699095328653368},
#    {'16534': 0.1272187010992453},
#    {'16544': 0.18676966744746906},
#    {'16635': 0.1724395891429554},
#    {'16756': 0.17010340226974155},
#    {'16781': 0.1340954862047383},
#    {'16803': 0.18776748816273253},
#    {'16860': 0.19717339970833841},
#    {'16870': 0.19600459788108898},
#    {'16899': 0.14763951003832},
#    {'16905': 0.2657701422926715},
#    {'16914': 0.11783762086990553},
#    {'16952': 0.245149227170892},
#    {'16959': 0.1708253093561727},
#    {'16992': 0.18343795093405246},
#    {'17035': 0.1339169250688335},
#    {'17126': 0.12806644818082072},
#    {'17193': 0.112364907991178},
#    {'17273': 0.15740004419532852},
#    {'17303': 0.16869350056471769},
#    {'17311': 0.2455128583263171},
#    {'17380': 0.113926628273744},
#    {'17427': 0.14071955924256543},
#    {'17429': 0.13429856857971242},
#    {'17469': 0.19085211434745858},
#    {'17495': 0.16853470157221048},
#    {'17516': 0.1367980077213027},
#    {'17563': 0.1388288269325451},
#    {'17607': 0.20811123421355307},
#    {'17626': 0.13730867748127507},
#    {'17687': 0.25423611788735995},
#    {'17715': 0.11601845679642735},
#    {'17750': 0.1263240956858624},
#    {'17836': 0.20008693172236106},
#    {'17871': 0.20011717216222039},
#    {'17879': 0.12699095328653368},
#    {'17978': 0.11273402296785252},
#    {'17979': 0.1283637462019258},
#    {'18022': 0.12640569086264195},
#    {'18053': 0.20811123421355307},
#    {'18068': 0.1390236928875034},
#    {'18108': 0.15113099493368531},
#    {'18119': 0.1340954862047383},
#    {'18214': 0.2564123428446136}])]

# %% [markdown]
# From above you can clearly see that this is what we wanted from inverted_index_tfidf.json file. Now lets look at other question how we can use this dictionary items combined with query for this we have written a function in **search_engine_processing.py** file named as **run_cosine_similarity_tfidf_conjunctive_query** which will get above dictionary and user entered query. Let me write the definition of that function and its related function which are

# %%
def run_cosine_similarity_tfidf_conjunctive_query(words, tdidf_inverted_index_items):
    query = list(words)

    # Each of the querys matches should contain all the words on the list query
    voc_dic = reading_of_data.get_vocabulary_dic()  # get a dictionary from dictionary file
    querys_matches = []
    for word in query:
        term_id = list(voc_dic.keys())[list(voc_dic.values()).index(word)]
        if term_id in tdidf_inverted_index_items.keys():
            querys_matches.append(list(tdidf_inverted_index_items[term_id]))
    # As a result we are going to have a list, with all the matches, called inter

    k = 0
    # documents_dictionary_with_tfidf = defaultdict(list)

    if len(querys_matches) > 0:
        inter = return_set_of_docs_from_tfidf_inverted_index_doc_item(querys_matches[k])
        k += 1
        for i in range(1, len(querys_matches)):
            inter = inter.intersection(return_set_of_docs_from_tfidf_inverted_index_doc_item(querys_matches[k]))
            k += 1

        documents_dictionary_with_tfidf = []

        for i in range(0, len(querys_matches)):
            common_docs = inter.intersection(return_set_of_docs_from_tfidf_inverted_index_doc_item(querys_matches[i]))
            documents_scores = get_tdidf_values_from_doc_ids(querys_matches[i], common_docs)
            documents_dictionary_with_tfidf.append(documents_scores)

        # I have 2D arry for each document in which columns contains tfidf values
        documents_dictionary_with_tfidf_matrix = np.array(documents_dictionary_with_tfidf)

        list_of_scores_for_query = []
        # I have to calculate the tdidf values for current sentence
        list_of_words = words
        voc_dic = reading_of_data.get_vocabulary_dic()  # get a dictionary from dictionary file
        voc_items = " ".join(voc_dic.values())
        sentence = " ".join(list_of_words)  # joining the sentence to use it later
        tfidf = TfidfVectorizer()
        tfidf_scores = tfidf.fit_transform([sentence])
        feature_names = tfidf.get_feature_names()
        for col in tfidf_scores.nonzero()[1]:
            word_item = feature_names[col]
            tfidf_score = tfidf_scores[0, col]
            list_of_scores_for_query.append(tfidf_score)

        # now I am going to calculate cosine similarity
        cosine_similarity_dictionary = defaultdict(str)
        for i in range(len(documents_dictionary_with_tfidf_matrix[0])):
            doc_n = documents_dictionary_with_tfidf_matrix[:, i]
            cosine_similarity_value = cosine(np.array(list_of_scores_for_query), doc_n)
            cosine_similarity_dictionary[list(common_docs)[i]] = cosine_similarity_value

        # sorting dictionary by value

        ordered_values = OrderedDict(sorted(cosine_similarity_dictionary.items(), key=lambda x: x[1]))

        priority_queue = []
        # priority queue
        for key, value in ordered_values.items():
            heapq.heappush(priority_queue,  (value * -1, key))

    return priority_queue
    # now we got the docs_ids which matched


def get_tdidf_values_from_doc_ids(items, common_docs):
    doc_ids = list()
    if len(items) > 0:
        for item in items:
            for key, value in item.items():  # iterating through dictionary it will only have one element
                for doc_id in common_docs:
                    if doc_id == key:
                        doc_ids.append(value)
                        break
    return doc_ids

# %% [markdown]
# For calculating consine similarity between two functions we have written a function named as cosine. It will get two vectors to caluclate the cosine similiraty between two docs.

# %%
def cosine(v1, v2):
    v1 = np.array(v1)
    v2 = np.array(v2)
    prodouct_of_both = np.dot(v1, v2)
    square_root_of_v1 = np.sqrt(np.sum(v1 ** 2))
    square_root_of_v2 = np.sqrt(np.sum(v2 ** 2))
    prodcuct_of_square_root_of_both = (square_root_of_v1 * square_root_of_v2)
    cosine_value = (prodouct_of_both / prodcuct_of_square_root_of_both)
    return cosine_value

# %% [markdown]
# Please also notice in run_cosine_similarity_tfidf_conjunctive_query function that we have used different librarires for differnt functionalties.
# 1. numpy for multiplying two vectors.
# 2. collections for defaultdict
# 3. heapq for heap queue. [Specifically Max heap.]
#
# There is no Max heap in python for this I have to multiply the actualy value to -1 before adding it to the queue and after getting its value from Queue. So the **run_cosine_similarity_tfidf_conjunctive_query** will return the proirity queue.
#
# Lets get the input from user and pass it to **run_cosine_similarity_tfidf_conjunctive_query** function.

# %%
query = input()
words = cleaning_of_data.remove_extras_from_query(query)
result_items = search_engine_processing.run_cosine_similarity_tfidf_conjunctive_query(words, inverted_index_dic)
# Out:
# Easy access to highway

# %% [markdown]
# We have result_items object which is priority queue. Lets pass it over to our output function named as **output_results_cosine_similarity** which resides it in **writing_of_data.py** file. Let me write definition of it here.

# %%
def output_results_cosine_similarity(folder_name, priority_queue):
    df = pd.DataFrame()
    cols_of_interest = ["Title", "Description", "City", "Url", "Similarity"]
    if priority_queue:
        value, key = heapq.heappop(priority_queue)
        doc_id = int(key)
        df = pd.read_csv(folder_name + "/doc_%s.tsv" % doc_id, sep="\t")
        df = df.rename(index=str,
                       columns={'title': 'Title',
                                "description": "Description", "city": "City", "url": 'Url'})
        df = df.filter(cols_of_interest, axis=1)
        df["Similarity"] = str((-1) * value)

        while priority_queue:
            value, key = heapq.heappop(priority_queue)
            doc_id = int(key)
            file = pd.read_csv(folder_name + "/doc_%s.tsv" % doc_id, sep="\t")
            file = file.rename(index=str, columns={'title': 'Title',
                                                   "description": "Description", "city": "City", "url": 'Url'})
            file["Similarity"] = str((-1) * value)
            df = df.append(file.filter(cols_of_interest, axis=1), ignore_index=True, sort=False)

        if df is not None:
            df.reset_index(drop=True, inplace=True)
            print(df.to_string())
            return df
        else:
            return
    else:
        print("No results were found with those characteristics")
        return

# %% [markdown]
# Lets see it in action. :)

# %%
df = writing_of_data.output_results_cosine_similarity(FOLDER_NAME_FOR_TSV_File, result_items)
df
# Out:
#                                                  Title  \
# 0                  Charm-Private Enrance-Good Location
# 1            Book for Superbowl! 4/5 bedroom, 3.5 bath
# 2    Beautiful home in Hurst. Easy access to Dallas/FW
# 3                         Superbowl Staycation Getaway
# 4                  Clean & Comfortable Room w/King Bed
# 5                       Private Room Near the Airports
# 6       Amazing House - Near Katy Mills and Water Park
# 7                                           Happy Home
# 8                  Bedroom near shopping peaceful area
# 9                           Private Room Near Airports
# 10         Large Quiet Private Room | Close to Airport
# 11    Charming Cottage close to the Alamo and Lackland
# 12                      S. Austin Great Location House
# 13                             SUPER BOWL WEEKEND 2017
# 14                       Spacious open home 2400 sqft.
# 15   Private Room | Quiet Space | Convenient to Air...
# 16                              Quiet Room Near Austin
# 17                 Luxury Apartment at La Cantera #106
# 18                            Houston Heights Homestay
# 19             Comfort/Style minutes from Downtown/TCU
# 20                   Cozy 1 bedroom/bathroom with pool
# 21                House 3 Blocks from Downtown, Uptown
# 22                  Remodeled - Near Downtown McKinney
# 23   Beautiful/Spacious house in convenient locatio...
# 24                                North Austin getaway
# 25                               Super Bowl Shangri La
# 26                   Inviting 3 BR house in NW Austin.
# 27    #1 2BR Ricchi Luxury Condo in San Antonio, Texas
# 28                    Cozy Private Room #1 Near Domain
# 29                 Single bedroom in a shared townhome
# ..                                                 ...
# 131   #2 2BR Ricchi Luxury Condo in San Antonio, Texas
# 132          Why stay at a hotel when you have a home?
# 133                 Private room and bath on far west!
# 134            Comfort/Style minutes from Downtown/TCU
# 135                             Room for Rent for SXSW
# 136                 The Cottage at Catalpa Corner Farm
# 137    New updated ranch home,acre yard with big trees
# 138  10 min to DFW airport, Six Flags, and AT&T Sta...
# 139                  Beautiful 2 bedroom/ 2 bath Condo
# 140                        Private luxury next to Dell
# 141        Large Quiet Private Room | Close to Airport
# 142  Open floor plan, party room, pool and comfy beds.
# 143                 Elegant/Modern Loft in Las Colinas
# 144                     Private Room Near the Airports
# 145                   Comfy, Cozy, Charming Efficiency
# 146     SUPERBOWL 2017 - Family Friendly Home For Rent
# 147     COZY FTW COTTAGE close to stockyard, Navy Base
# 148  10 min to DFW airport, Six Flags, and AT&T Sta...
# 149      Far North Dallas private room and bath w/pool
# 150                                        Casita Arte
# 151  10 min to DFW airport, Six Flags, and AT&T Sta...
# 152                      Cozy Room in South Fort Worth
# 153         Beautiful 3/2 home 5 miles from Texas A&M.
# 154   Clean, Quiet and Cozy - Two Private Rooms & Bath
# 155                                Home away from home
# 156              19 Foot Airstream Bambi International
# 157                 Remodeled - Near Downtown McKinney
# 158  10 min to DFW airport, Six Flags, and AT&T Sta...
# 159                 Renovated, 7 Mls From Randolph AFB
# 160                         Private Room Near Airports
#
#                                            Description             City  \
# 0    With its own bath and your own private entranc...      San Antonio
# 1    30 minutes from NRG Stadium. My place is close...          Houston
# 2    Beautiful single story home completely updated...            Hurst
# 3    My place is close to restaurants and dining, q...       Sugar Land
# 4    Great location, easy access to the beach, kite...   Corpus Christi
# 5    One of three private rooms in a two story home...           Irving
# 6    Our house is beautiful, conveniently located, ...             Katy
# 7    This happy home is located very close to resta...       Fort Worth
# 8    Our one bedroom is located in a nice two story...         Converse
# 9    One of three private rooms in a two story home...           Irving
# 10   Large private room with sitting area and spaci...      San Antonio
# 11   Charming historic upstairs private apartment l...      San Antonio
# 12   Cozy and cute house in the convenient South Au...           Austin
# 13   My place is close to great views, the airport,...         Richmond
# 14   Enjoy peaceful &amp; clean neighborhood. Spaci...           Dallas
# 15   Private room within a beautiful cozy home. Loc...      San Antonio
# 16   Clean &amp; spacious modern home with private ...       Cedar Park
# 17   At Ricchi you will have the best location in S...      San Antonio
# 18   Guest Room is on the first floor with attached...          Houston
# 19   My place is close to a variety of area restaur...         Benbrook
# 20   My cool and comfortable bedroom apartment feel...           Irving
# 21   This very unique charming home is one of the c...           Dallas
# 22   Beautiful remodeled 3 bedroom, 2 bath home jus...         McKinney
# 23   My place is close to major highways for easy a...          Houston
# 24   Close to Major highway and toll\nAccess. Howar...           Austin
# 25   My place is close to restaurants and dining an...           Spring
# 26   My place is close to restaurants and dining in...           Austin
# 27   We have promo rates until July 15! Key in your...      San Antonio
# 28   Private room with shared guest bath in a 4BR h...           Austin
# 29   Easy access to 410 and highway 151... About 15...      San Antonio
# ..                                                 ...              ...
# 131  We have promo rates until July 15! Key in your...      San Antonio
# 132  Travellers, professionals, this is the place t...      San Antonio
# 133  Inexpensive, simple alternative to a hotel/mot...      San Antonio
# 134  My place is close to a variety of area restaur...         Benbrook
# 135  Large house located 12 miles from downtown, ea...             Buda
# 136  Enjoy your stay in East Texas with views of ro...          Lindale
# 137  My place is close to Katy mills mall and water...             Katy
# 138  A short 10 minutes from DFW, only 20 minutes t...           Euless
# 139  Very calm, quiet, and relaxing environment. Ga...      San Antonio
# 140  Upscale, first floor, quiet one bedroom apartm...       Round Rock
# 141  Large private room with sitting area and spaci...      San Antonio
# 142  Nice home with open floor plan, large party ro...      San Antonio
# 143  This elegant and modernly designed two-story l...           Irving
# 144  One of three private rooms in a two story home...           Irving
# 145  In the heart of the town of Natalia, comfy eff...          Natalia
# 146  Fully furnished home available for 2017 Super ...          Houston
# 147  This quaint Cozy FTW Cottage has tons of chara...       Fort Worth
# 148  A short 10 minutes from DFW, only 20 minutes t...           Euless
# 149  Private room available in Far North Dallas hom...           Dallas
# 150  Relax in this open space where art mixes with ...      San Antonio
# 151  A short 10 minutes from DFW, only 20 minutes t...           Euless
# 152  Private room and bathroom with room for one or...       Fort Worth
# 153  Lovely one story 2,300 sq. ft., 3 bedrooms 2 b...  College Station
# 154  Our place is friendly, clean and cozy, with no...     Pflugerville
# 155  My cool comfortable3 bedroom home with plenty ...       Carrollton
# 156  My place is close to Downtown, Easy access to ...           Austin
# 157  Beautiful remodeled 3 bedroom, 2 bath home jus...         McKinney
# 158  A short 10 minutes from DFW, only 20 minutes t...           Euless
# 159  This newly remodeled, stylishly decorated home...      San Antonio
# 160  One of three private rooms in a two story home...           Irving
#
#                                                    Url          Similarity
# 0    https://www.airbnb.com/rooms/5183096?location=...  0.9933205307927605
# 1    https://www.airbnb.com/rooms/16056676?location...  0.9933205307927605
# 2    https://www.airbnb.com/rooms/14917951?location...  0.9933205307927604
# 3    https://www.airbnb.com/rooms/16854595?location...  0.9933205307927604
# 4    https://www.airbnb.com/rooms/14057644?location...  0.9933205307927604
# 5    https://www.airbnb.com/rooms/13602580?location...  0.9933205307927604
# 6    https://www.airbnb.com/rooms/15911826?location...  0.9933205307927604
# 7    https://www.airbnb.com/rooms/14782837?location...  0.9933205307927604
# 8    https://www.airbnb.com/rooms/12201369?location...  0.9933205307927604
# 9    https://www.airbnb.com/rooms/13604316?location...  0.9933205307927604
# 10   https://www.airbnb.com/rooms/19073250?location...  0.9933205307927604
# 11   https://www.airbnb.com/rooms/16873297?location...  0.9933205307927603
# 12   https://www.airbnb.com/rooms/10309872?location...  0.9933205307927603
# 13   https://www.airbnb.com/rooms/14991163?location...  0.9933205307927603
# 14   https://www.airbnb.com/rooms/19117708?location...  0.9933205307927603
# 15   https://www.airbnb.com/rooms/19038050?location...  0.9933205307927603
# 16   https://www.airbnb.com/rooms/18518056?location...  0.9933205307927603
# 17   https://www.airbnb.com/rooms/5036358?location=...  0.9933205307927602
# 18   https://www.airbnb.com/rooms/536807?location=B...  0.9933205307927602
# 19   https://www.airbnb.com/rooms/14770806?location...  0.9933205307927602
# 20   https://www.airbnb.com/rooms/7276294?location=...  0.9933205307927602
# 21   https://www.airbnb.com/rooms/12115172?location...  0.9933205307927602
# 22   https://www.airbnb.com/rooms/3522884?location=...  0.9933205307927602
# 23   https://www.airbnb.com/rooms/16334186?location...  0.9933205307927602
# 24   https://www.airbnb.com/rooms/18720660?location...  0.9933205307927602
# 25   https://www.airbnb.com/rooms/17000855?location...  0.9933205307927602
# 26   https://www.airbnb.com/rooms/14651757?location...  0.9933205307927602
# 27   https://www.airbnb.com/rooms/10783113?location...   0.986157019466115
# 28   https://www.airbnb.com/rooms/14163045?location...   0.986157019466115
# 29   https://www.airbnb.com/rooms/19205457?location...   0.986157019466115
# ..                                                 ...                 ...
# 131  https://www.airbnb.com/rooms/13207987?location...  0.9861570194661148
# 132  https://www.airbnb.com/rooms/1633767?location=...  0.9861570194661148
# 133  https://www.airbnb.com/rooms/16147758?location...  0.9861570194661148
# 134  https://www.airbnb.com/rooms/14770806?location...  0.9861570194661148
# 135  https://www.airbnb.com/rooms/2431585?location=...  0.9861570194661147
# 136  https://www.airbnb.com/rooms/16775972?location...  0.9861570194661147
# 137  https://www.airbnb.com/rooms/15501301?location...  0.9861570194661147
# 138  https://www.airbnb.com/rooms/7038625?location=...  0.9861570194661147
# 139  https://www.airbnb.com/rooms/17176922?location...  0.9861570194661147
# 140  https://www.airbnb.com/rooms/11714131?location...  0.9861570194661147
# 141  https://www.airbnb.com/rooms/19073250?location...  0.9861570194661147
# 142  https://www.airbnb.com/rooms/19442323?location...  0.9861570194661147
# 143  https://www.airbnb.com/rooms/9805537?location=...  0.9861570194661147
# 144  https://www.airbnb.com/rooms/13602580?location...  0.9861570194661147
# 145  https://www.airbnb.com/rooms/18288485?location...  0.9861570194661147
# 146  https://www.airbnb.com/rooms/16811771?location...  0.9861570194661147
# 147  https://www.airbnb.com/rooms/11778807?location...  0.9861570194661147
# 148  https://www.airbnb.com/rooms/7038625?location=...  0.9780833525297535
# 149  https://www.airbnb.com/rooms/19314043?location...  0.9780833525297534
# 150  https://www.airbnb.com/rooms/18025345?location...  0.9780833525297534
# 151  https://www.airbnb.com/rooms/18341099?location...  0.9780833525297534
# 152  https://www.airbnb.com/rooms/16911814?location...  0.9780833525297534
# 153  https://www.airbnb.com/rooms/14469997?location...  0.9780833525297534
# 154  https://www.airbnb.com/rooms/15813913?location...  0.9572512780500526
# 155  https://www.airbnb.com/rooms/16392671?location...  0.9572512780500526
# 156  https://www.airbnb.com/rooms/14530422?location...  0.9572512780500525
# 157  https://www.airbnb.com/rooms/3522884?location=...  0.9572512780500525
# 158  https://www.airbnb.com/rooms/18341099?location...  0.9572512780500523
# 159  https://www.airbnb.com/rooms/8404006?location=...  0.9572512780500523
# 160  https://www.airbnb.com/rooms/13604316?location...  0.8573739085673792
#
# [161 rows x 5 columns]

# %% [markdown]
# You can clearly see the difference while looking at Similarity function. Now above section is completed for combining **Conjunctive query & Ranking score**. Lets move onto next part. All the above functionality code is inside the **search_engine.py** file which completes our script.

# %% [markdown]
# ### Step 4: Define a new score!

# %%
import pandas as pd

# %% [markdown]
# To define the new score, we use the following variables:
# 1. average_rate_per_night
# 2. bedrooms_count
# 3. city
# 4. date_of_listing
#
# Following we explain the functions that were used to compute the score, in each of the variables

# %% [markdown]
# #### 1. Average rate per night:
#
# This function compares the ideal rate for the user, which is explicitly asked, and the actual rate per nigth of each Airbnb, called by the variable doc_rate. Resulting in a rate between 0 and 1, called rate_score.
#
# - The maximum rate_score you can have is 1, and it is reached when user_rate = doc_rate.
# - The minimum rate_score you can have is 0, and it is reached when doc_rate it's more than 30 dollars away from user_rate
# - The intermediate values are given by areas around our variable of interest: user_rate, giving more points to values closer and less to the farthest.

# %%
def rate_score(user_rate, doc_rate):
    if user_rate == doc_rate:
        rate_score = 1
    elif user_rate - 10 <= doc_rate <= user_rate + 10:
        rate_score = 0.75
    elif user_rate - 20 <= doc_rate <= user_rate + 20:
        rate_score = 0.5
    elif user_rate - 30 <= doc_rate <= user_rate + 30:
        rate_score = 0.25
    else:
        rate_score = 0
    return rate_score

# %%
rate_score(25, 45)
# Out:
# 0.5

# %%
def get_data_frame_from_priority_queue(folder_name, priority_queue):
    df = pd.DataFrame()
    cols_of_interest = ["Title", "Description", "City", "Url", "Similarity"]
    if priority_queue:
        value, key = heapq.heappop(priority_queue)
        doc_id = int(key)
        df = pd.read_csv(folder_name + "/doc_%s.tsv" % doc_id, sep="\t")
        df["Similarity"] = str((-1) * value)

        while priority_queue:
            value, key = heapq.heappop(priority_queue)
            doc_id = int(key)
            file = pd.read_csv(folder_name + "/doc_%s.tsv" % doc_id, sep="\t")
            file["Similarity"] = str((-1) * value)
            df = df.append(file, ignore_index=True, sort=False)

        if df is not None:
            df.reset_index(drop=True, inplace=True)
            # print(df.to_string())
            return df
        else:
            return
    else:
        print("No results were found with those characteristics")
        return

# %% [markdown]
# Now we need whole dataframe rows rather than intrested rows which we get from above function.

# %%
import heapq
dataframe = get_data_frame_from_priority_queue(FOLDER_NAME_FOR_TSV_File, result_items)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-aec0eb66d8bc> in <module>()
#       1 import heapq
#       2 dataframe = get_data_frame_from_priority_queue(FOLDER_NAME_FOR_TSV_File, result_items)
# ----> 3 datframe
#
# NameError: name 'datframe' is not defined

# %%
dataframe
# Out:
#      Unnamed: 0  Unnamed: 0.1 average_rate_per_night bedrooms_count  \
# 0         16697         16698                    $45              1
# 1          3186          3187                  $1000              4
# 2          1553          1554                   $150              3
# 3         15627         15628                  $2000              4
# 4          2149          2150                    $90              1
# 5          2414          2415                    $38              1
# 6          3223          3224                   $289              4
# 7          3601          3602                    $37              1
# 8          5856          5857                    $45              1
# 9          5986          5987                    $36              1
# 10         6841          6842                    $50              1
# 11        11525         11526                    $75              2
# 12        12475         12476                   $195              3
# 13          155           156                   $768              2
# 14        18185         18186                   $150              4
# 15         4039          4040                    $40              1
# 16         7712          7713                    $50              1
# 17        11918         11919                   $250              3
# 18        12601         12602                    $57              1
# 19        12785         12786                    $25              1
# 20        13153         13154                    $65              1
# 21        14732         14733                   $200              2
# 22        14995         14996                   $155              3
# 23        15836         15837                   $100              3
# 24         2383          2384                    $70              1
# 25         5741          5742                   $950              4
# 26         8352          8353                   $150              3
# 27        10273         10274                   $139              2
# 28        10898         10899                    $35              1
# 29        11180         11181                    $25              1
# ..          ...           ...                    ...            ...
# 131        8741          8742                   $139              2
# 132        8913          8914                    $45              1
# 133        9148          9149                    $18              1
# 134        9725          9726                    $25              1
# 135       10169         10170                   $200              1
# 136        1197          1198                    $81              2
# 137       13061         13062                   $400              3
# 138       14758         14759                    $40              1
# 139       17578         17579                    $65              2
# 140        2356          2357                    $91              1
# 141        2682          2683                    $50              1
# 142        2772          2773                   $139              3
# 143        2909          2910                    $99              1
# 144        4421          4422                    $38              1
# 145        4523          4524                    $46         Studio
# 146        7634          7635                  $2000              2
# 147        7958          7959                   $120              2
# 148        8760          8761                    $40              1
# 149       15074         15075                    $72              1
# 150       16422         16423                    $65              1
# 151        1710          1711                    $40              1
# 152         450           451                    $30              1
# 153        8584          8585                   $750              3
# 154        2276          2277                   $100              1
# 155        7108          7109                    $50              1
# 156        3182          3183                    $75         Studio
# 157        9318          9319                   $155              3
# 158       12098         12099                    $40              1
# 159        2913          2914                   $185              2
# 160        3549          3550                    $36              1
# 22   Beautiful remodeled 3 bedroom, 2 bath home jus...  33.192434 -96.642465
# 23   My place is close to major highways for easy a...  29.659373 -95.542636
# 24   Close to Major highway and toll\nAccess. Howar...  30.440253 -97.694393
# 25   My place is close to restaurants and dining an...  30.133220 -95.387730
# 26   My place is close to restaurants and dining in...  30.469885 -97.778484
# 27   We have promo rates until July 15! Key in your...  29.610547 -98.594406
# 28   Private room with shared guest bath in a 4BR h...  30.424197 -97.696490
# 29   Easy access to 410 and highway 151... About 15...  29.419302 -98.671484
# ..                                                 ...        ...        ...
# 131  We have promo rates until July 15! Key in your...  29.610386 -98.596384
# 132  Travellers, professionals, this is the place t...  29.518302 -98.726089
# 133  Inexpensive, simple alternative to a hotel/mot...  29.439991 -98.705548
# 134  My place is close to a variety of area restaur...  32.692764 -97.418444
# 135  Large house located 12 miles from downtown, ea...  30.060143 -97.827560
# 136  Enjoy your stay in East Texas with views of ro...  32.524937 -95.570954
# 137  My place is close to Katy mills mall and water...  29.757463 -95.809661
# 138  A short 10 minutes from DFW, only 20 minutes t...  32.820033 -97.092709
# 139  Very calm, quiet, and relaxing environment. Ga...  29.535162 -98.411669
# 140  Upscale, first floor, quiet one bedroom apartm...  30.487864 -97.654912
# 141  Large private room with sitting area and spaci...  29.574321 -98.450904
# 142  Nice home with open floor plan, large party ro...  29.521901 -98.447902
# 143  This elegant and modernly designed two-story l...  32.855156 -96.950938
# 144  One of three private rooms in a two story home...  32.930455 -96.965192
# 145  In the heart of the town of Natalia, comfy eff...  29.190306 -98.862756
# 146  Fully furnished home available for 2017 Super ...  29.718378 -95.671856
# 147  This quaint Cozy FTW Cottage has tons of chara...  32.768437 -97.403865
# 148  A short 10 minutes from DFW, only 20 minutes t...  32.820033 -97.092709
# 149  Private room available in Far North Dallas hom...  32.982801 -96.775461
# 150  Relax in this open space where art mixes with ...  29.473343 -98.525326
# 151  A short 10 minutes from DFW, only 20 minutes t...  32.818345 -97.092519
# 152  Private room and bathroom with room for one or...  32.627374 -97.373738
# 153  Lovely one story 2,300 sq. ft., 3 bedrooms 2 b...  30.660078 -96.267918
# 154  Our place is friendly, clean and cozy, with no...  30.460960 -97.583181
# 155  My cool comfortable3 bedroom home with plenty ...  32.987474 -96.876661
# 156  My place is close to Downtown, Easy access to ...  30.385996 -97.748745
# 157  Beautiful remodeled 3 bedroom, 2 bath home jus...  33.192434 -96.642465
# 158  A short 10 minutes from DFW, only 20 minutes t...  32.818345 -97.092519
# 159  This newly remodeled, stylishly decorated home...  29.564935 -98.369662
# 160  One of three private rooms in a two story home...  32.929012 -96.966895
#
#                                                  title  \
# 0                  Charm-Private Enrance-Good Location
# 1            Book for Superbowl! 4/5 bedroom, 3.5 bath
# 2    Beautiful home in Hurst. Easy access to Dallas/FW
# 3                         Superbowl Staycation Getaway
# 4                  Clean & Comfortable Room w/King Bed
# 5                       Private Room Near the Airports
# 6       Amazing House - Near Katy Mills and Water Park
# 7                                           Happy Home
# 8                  Bedroom near shopping peaceful area
# 9                           Private Room Near Airports
# 10         Large Quiet Private Room | Close to Airport
# 11    Charming Cottage close to the Alamo and Lackland
# 12                      S. Austin Great Location House
# 13                             SUPER BOWL WEEKEND 2017
# 14                       Spacious open home 2400 sqft.
# 15   Private Room | Quiet Space | Convenient to Air...
# 16                              Quiet Room Near Austin
# 17                 Luxury Apartment at La Cantera #106
# 18                            Houston Heights Homestay
# 19             Comfort/Style minutes from Downtown/TCU
# 20                   Cozy 1 bedroom/bathroom with pool
# 21                House 3 Blocks from Downtown, Uptown
# 22                  Remodeled - Near Downtown McKinney
# 23   Beautiful/Spacious house in convenient locatio...
# 24                                North Austin getaway
# 25                               Super Bowl Shangri La
# 26                   Inviting 3 BR house in NW Austin.
# 27    #1 2BR Ricchi Luxury Condo in San Antonio, Texas
# 28                    Cozy Private Room #1 Near Domain
# 29                 Single bedroom in a shared townhome
# ..                                                 ...
# 131   #2 2BR Ricchi Luxury Condo in San Antonio, Texas
# 132          Why stay at a hotel when you have a home?
# 133                 Private room and bath on far west!
# 134            Comfort/Style minutes from Downtown/TCU
# 135                             Room for Rent for SXSW
# 136                 The Cottage at Catalpa Corner Farm
# 137    New updated ranch home,acre yard with big trees
# 138  10 min to DFW airport, Six Flags, and AT&T Sta...
# 139                  Beautiful 2 bedroom/ 2 bath Condo
# 140                        Private luxury next to Dell
# 141        Large Quiet Private Room | Close to Airport
# 142  Open floor plan, party room, pool and comfy beds.
# 143                 Elegant/Modern Loft in Las Colinas
# 144                     Private Room Near the Airports
# 145                   Comfy, Cozy, Charming Efficiency
# 146     SUPERBOWL 2017 - Family Friendly Home For Rent
# 147     COZY FTW COTTAGE close to stockyard, Navy Base
# 148  10 min to DFW airport, Six Flags, and AT&T Sta...
# 149      Far North Dallas private room and bath w/pool
# 150                                        Casita Arte
# 151  10 min to DFW airport, Six Flags, and AT&T Sta...
# 152                      Cozy Room in South Fort Worth
# 153         Beautiful 3/2 home 5 miles from Texas A&M.
# 154   Clean, Quiet and Cozy - Two Private Rooms & Bath
# 155                                Home away from home
# 156              19 Foot Airstream Bambi International
# 157                 Remodeled - Near Downtown McKinney
# 158  10 min to DFW airport, Six Flags, and AT&T Sta...
# 159                 Renovated, 7 Mls From Randolph AFB
# 160                         Private Room Near Airports
#
#                                                    url          Similarity
# 0    https://www.airbnb.com/rooms/5183096?location=...  0.9933205307927605
# 1    https://www.airbnb.com/rooms/16056676?location...  0.9933205307927605
# 2    https://www.airbnb.com/rooms/14917951?location...  0.9933205307927604
# 3    https://www.airbnb.com/rooms/16854595?location...  0.9933205307927604
# 4    https://www.airbnb.com/rooms/14057644?location...  0.9933205307927604
# 5    https://www.airbnb.com/rooms/13602580?location...  0.9933205307927604
# 6    https://www.airbnb.com/rooms/15911826?location...  0.9933205307927604
# 7    https://www.airbnb.com/rooms/14782837?location...  0.9933205307927604
# 8    https://www.airbnb.com/rooms/12201369?location...  0.9933205307927604
# 9    https://www.airbnb.com/rooms/13604316?location...  0.9933205307927604
# 10   https://www.airbnb.com/rooms/19073250?location...  0.9933205307927604
# 11   https://www.airbnb.com/rooms/16873297?location...  0.9933205307927603
# 12   https://www.airbnb.com/rooms/10309872?location...  0.9933205307927603
# 13   https://www.airbnb.com/rooms/14991163?location...  0.9933205307927603
# 14   https://www.airbnb.com/rooms/19117708?location...  0.9933205307927603
# 15   https://www.airbnb.com/rooms/19038050?location...  0.9933205307927603
# 16   https://www.airbnb.com/rooms/18518056?location...  0.9933205307927603
# 17   https://www.airbnb.com/rooms/5036358?location=...  0.9933205307927602
# 18   https://www.airbnb.com/rooms/536807?location=B...  0.9933205307927602
# 19   https://www.airbnb.com/rooms/14770806?location...  0.9933205307927602
# 20   https://www.airbnb.com/rooms/7276294?location=...  0.9933205307927602
# 21   https://www.airbnb.com/rooms/12115172?location...  0.9933205307927602
# 22   https://www.airbnb.com/rooms/3522884?location=...  0.9933205307927602
# 23   https://www.airbnb.com/rooms/16334186?location...  0.9933205307927602
# 24   https://www.airbnb.com/rooms/18720660?location...  0.9933205307927602
# 25   https://www.airbnb.com/rooms/17000855?location...  0.9933205307927602
# 26   https://www.airbnb.com/rooms/14651757?location...  0.9933205307927602
# 27   https://www.airbnb.com/rooms/10783113?location...   0.986157019466115
# 28   https://www.airbnb.com/rooms/14163045?location...   0.986157019466115
# 29   https://www.airbnb.com/rooms/19205457?location...   0.986157019466115
# ..                                                 ...                 ...
# 131  https://www.airbnb.com/rooms/13207987?location...  0.9861570194661148
# 132  https://www.airbnb.com/rooms/1633767?location=...  0.9861570194661148
# 133  https://www.airbnb.com/rooms/16147758?location...  0.9861570194661148
# 134  https://www.airbnb.com/rooms/14770806?location...  0.9861570194661148
# 135  https://www.airbnb.com/rooms/2431585?location=...  0.9861570194661147
# 136  https://www.airbnb.com/rooms/16775972?location...  0.9861570194661147
# 137  https://www.airbnb.com/rooms/15501301?location...  0.9861570194661147
# 138  https://www.airbnb.com/rooms/7038625?location=...  0.9861570194661147
# 139  https://www.airbnb.com/rooms/17176922?location...  0.9861570194661147
# 140  https://www.airbnb.com/rooms/11714131?location...  0.9861570194661147
# 141  https://www.airbnb.com/rooms/19073250?location...  0.9861570194661147
# 142  https://www.airbnb.com/rooms/19442323?location...  0.9861570194661147
# 143  https://www.airbnb.com/rooms/9805537?location=...  0.9861570194661147
# 144  https://www.airbnb.com/rooms/13602580?location...  0.9861570194661147
# 145  https://www.airbnb.com/rooms/18288485?location...  0.9861570194661147
# 146  https://www.airbnb.com/rooms/16811771?location...  0.9861570194661147
# 147  https://www.airbnb.com/rooms/11778807?location...  0.9861570194661147
# 148  https://www.airbnb.com/rooms/7038625?location=...  0.9780833525297535
# 149  https://www.airbnb.com/rooms/19314043?location...  0.9780833525297534
# 150  https://www.airbnb.com/rooms/18025345?location...  0.9780833525297534
# 151  https://www.airbnb.com/rooms/18341099?location...  0.9780833525297534
# 152  https://www.airbnb.com/rooms/16911814?location...  0.9780833525297534
# 153  https://www.airbnb.com/rooms/14469997?location...  0.9780833525297534
# 154  https://www.airbnb.com/rooms/15813913?location...  0.9572512780500526
# 155  https://www.airbnb.com/rooms/16392671?location...  0.9572512780500526
# 156  https://www.airbnb.com/rooms/14530422?location...  0.9572512780500525
# 157  https://www.airbnb.com/rooms/3522884?location=...  0.9572512780500525
# 158  https://www.airbnb.com/rooms/18341099?location...  0.9572512780500523
# 159  https://www.airbnb.com/rooms/8404006?location=...  0.9572512780500523
# 160  https://www.airbnb.com/rooms/13604316?location...  0.8573739085673792
#
# [161 rows x 12 columns]

# %%
df = dataframe
# Remove the $ 
df['average_rate_per_night'] = df['average_rate_per_night'].str.replace("$", '')
# Convert to integer
df['average_rate_per_night'] = pd.to_numeric(df['average_rate_per_night'])

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  average_rate_per_night bedrooms_count  \
# 0         16697         16698                      45              1
# 1          3186          3187                    1000              4
# 2          1553          1554                     150              3
# 3         15627         15628                    2000              4
# 4          2149          2150                      90              1
# 5          2414          2415                      38              1
# 6          3223          3224                     289              4
# 7          3601          3602                      37              1
# 8          5856          5857                      45              1
# 9          5986          5987                      36              1
# 10         6841          6842                      50              1
# 11        11525         11526                      75              2
# 12        12475         12476                     195              3
# 13          155           156                     768              2
# 14        18185         18186                     150              4
# 15         4039          4040                      40              1
# 16         7712          7713                      50              1
# 17        11918         11919                     250              3
# 18        12601         12602                      57              1
# 19        12785         12786                      25              1
# 20        13153         13154                      65              1
# 21        14732         14733                     200              2
# 22        14995         14996                     155              3
# 23        15836         15837                     100              3
# 24         2383          2384                      70              1
# 25         5741          5742                     950              4
  \
# 0                  Charm-Private Enrance-Good Location
# 1            Book for Superbowl! 4/5 bedroom, 3.5 bath
# 2    Beautiful home in Hurst. Easy access to Dallas/FW
# 3                         Superbowl Staycation Getaway
# 4                  Clean & Comfortable Room w/King Bed
# 5                       Private Room Near the Airports
# 6       Amazing House - Near Katy Mills and Water Park
# 7                                           Happy Home
# 8                  Bedroom near shopping peaceful area
# 9                           Private Room Near Airports
# 10         Large Quiet Private Room | Close to Airport
# 11    Charming Cottage close to the Alamo and Lackland
# 12                      S. Austin Great Location House
# 13                             SUPER BOWL WEEKEND 2017
# 14                       Spacious open home 2400 sqft.
# 15   Private Room | Quiet Space | Convenient to Air...
# 16                              Quiet Room Near Austin
# 17                 Luxury Apartment at La Cantera #106
# 18                            Houston Heights Homestay
# 19             Comfort/Style minutes from Downtown/TCU
# 20                   Cozy 1 bedroom/bathroom with pool
# 21                House 3 Blocks from Downtown, Uptown
# 22                  Remodeled - Near Downtown McKinney
# 23   Beautiful/Spacious house in convenient locatio...
# 24                                North Austin getaway
# 25                               Super Bowl Shangri La
# 26                   Inviting 3 BR house in NW Austin.
# 27    #1 2BR Ricchi Luxury Condo in San Antonio, Texas
# 28                    Cozy Private Room #1 Near Domain
# 29                 Single bedroom in a shared townhome
# ..                                                 ...
# 131   #2 2BR Ricchi Luxury Condo in San Antonio, Texas
# 132          Why stay at a hotel when you have a home?
# 133                 Private room and bath on far west!
# 134            Comfort/Style minutes from Downtown/TCU
# 135                             Room for Rent for SXSW
# 136                 The Cottage at Catalpa Corner Farm
# 137    New updated ranch home,acre yard with big trees
# 138  10 min to DFW airport, Six Flags, and AT&T Sta...
# 139                  Beautiful 2 bedroom/ 2 bath Condo
# 140                        Private luxury next to Dell
# 141        Large Quiet Private Room | Close to Airport
# 142  Open floor plan, party room, pool and comfy beds.
# 143                 Elegant/Modern Loft in Las Colinas
# 144                     Private Room Near the Airports
# 145                   Comfy, Cozy, Charming Efficiency
# 146     SUPERBOWL 2017 - Family Friendly Home For Rent
# 147     COZY FTW COTTAGE close to stockyard, Navy Base
# 148  10 min to DFW airport, Six Flags, and AT&T Sta...
# 149      Far North Dallas private room and bath w/pool
# 150                                        Casita Arte
# 151  10 min to DFW airport, Six Flags, and AT&T Sta...
# 152                      Cozy Room in South Fort Worth
# 153         Beautiful 3/2 home 5 miles from Texas A&M.
# 154   Clean, Quiet and Cozy - Two Private Rooms & Bath
# 155                                Home away from home
# 156              19 Foot Airstream Bambi International
# 157                 Remodeled - Near Downtown McKinney
# 158  10 min to DFW airport, Six Flags, and AT&T Sta...
# 159                 Renovated, 7 Mls From Randolph AFB
# 160                         Private Room Near Airports
#
#                                                    url          Similarity
# 0    https://www.airbnb.com/rooms/5183096?location=...  0.9933205307927605
# 1    https://www.airbnb.com/rooms/16056676?location...  0.9933205307927605
# 2    https://www.airbnb.com/rooms/14917951?location...  0.9933205307927604
# 3    https://www.airbnb.com/rooms/16854595?location...  0.9933205307927604
# 4    https://www.airbnb.com/rooms/14057644?location...  0.9933205307927604
# 5    https://www.airbnb.com/rooms/13602580?location...  0.9933205307927604
# 6    https://www.airbnb.com/rooms/15911826?location...  0.9933205307927604
# 7    https://www.airbnb.com/rooms/14782837?location...  0.9933205307927604
# 8    https://www.airbnb.com/rooms/12201369?location...  0.9933205307927604
# 9    https://www.airbnb.com/rooms/13604316?location...  0.9933205307927604
# 10   https://www.airbnb.com/rooms/19073250?location...  0.9933205307927604
# 11   https://www.airbnb.com/rooms/16873297?location...  0.9933205307927603
# 12   https://www.airbnb.com/rooms/10309872?location...  0.9933205307927603
# 13   https://www.airbnb.com/rooms/14991163?location...  0.9933205307927603
# 14   https://www.airbnb.com/rooms/19117708?location...  0.9933205307927603
# 15   https://www.airbnb.com/rooms/19038050?location...  0.9933205307927603
# 16   https://www.airbnb.com/rooms/18518056?location...  0.9933205307927603
# 17   https://www.airbnb.com/rooms/5036358?location=...  0.9933205307927602
# 18   https://www.airbnb.com/rooms/536807?location=B...  0.9933205307927602
# 19   https://www.airbnb.com/rooms/14770806?location...  0.9933205307927602
# 20   https://www.airbnb.com/rooms/7276294?location=...  0.9933205307927602
# 21   https://www.airbnb.com/rooms/12115172?location...  0.9933205307927602
# 22   https://www.airbnb.com/rooms/3522884?location=...  0.9933205307927602
# 23   https://www.airbnb.com/rooms/16334186?location...  0.9933205307927602
# 24   https://www.airbnb.com/rooms/18720660?location...  0.9933205307927602
# 25   https://www.airbnb.com/rooms/17000855?location...  0.9933205307927602
# 26   https://www.airbnb.com/rooms/14651757?location...  0.9933205307927602
# 27   https://www.airbnb.com/rooms/10783113?location...   0.986157019466115
# 28   https://www.airbnb.com/rooms/14163045?location...   0.986157019466115
# 29   https://www.airbnb.com/rooms/19205457?location...   0.986157019466115
# ..                                                 ...                 ...
# 131  https://www.airbnb.com/rooms/13207987?location...  0.9861570194661148
# 132  https://www.airbnb.com/rooms/1633767?location=...  0.9861570194661148
# 133  https://www.airbnb.com/rooms/16147758?location...  0.9861570194661148
# 134  https://www.airbnb.com/rooms/14770806?location...  0.9861570194661148
# 135  https://www.airbnb.com/rooms/2431585?location=...  0.9861570194661147
# 136  https://www.airbnb.com/rooms/16775972?location...  0.9861570194661147
# 137  https://www.airbnb.com/rooms/15501301?location...  0.9861570194661147
# 138  https://www.airbnb.com/rooms/7038625?location=...  0.9861570194661147
# 139  https://www.airbnb.com/rooms/17176922?location...  0.9861570194661147
# 140  https://www.airbnb.com/rooms/11714131?location...  0.9861570194661147
# 141  https://www.airbnb.com/rooms/19073250?location...  0.9861570194661147
# 142  https://www.airbnb.com/rooms/19442323?location...  0.9861570194661147
# 143  https://www.airbnb.com/rooms/9805537?location=...  0.9861570194661147
# 144  https://www.airbnb.com/rooms/13602580?location...  0.9861570194661147
# 145  https://www.airbnb.com/rooms/18288485?location...  0.9861570194661147
# 146  https://www.airbnb.com/rooms/16811771?location...  0.9861570194661147
# 147  https://www.airbnb.com/rooms/11778807?location...  0.9861570194661147
# 148  https://www.airbnb.com/rooms/7038625?location=...  0.9780833525297535
# 149  https://www.airbnb.com/rooms/19314043?location...  0.9780833525297534
# 150  https://www.airbnb.com/rooms/18025345?location...  0.9780833525297534
# 151  https://www.airbnb.com/rooms/18341099?location...  0.9780833525297534
# 152  https://www.airbnb.com/rooms/16911814?location...  0.9780833525297534
# 153  https://www.airbnb.com/rooms/14469997?location...  0.9780833525297534
# 154  https://www.airbnb.com/rooms/15813913?location...  0.9572512780500526
# 155  https://www.airbnb.com/rooms/16392671?location...  0.9572512780500526
# 156  https://www.airbnb.com/rooms/14530422?location...  0.9572512780500525
# 157  https://www.airbnb.com/rooms/3522884?location=...  0.9572512780500525
# 158  https://www.airbnb.com/rooms/18341099?location...  0.9572512780500523
# 159  https://www.airbnb.com/rooms/8404006?location=...  0.9572512780500523
# 160  https://www.airbnb.com/rooms/13604316?location...  0.8573739085673792
#
# [161 rows x 12 columns]

# %% [markdown]
# In order to execute the previous function, we need to make some small modifications to the data as removing the dollar sign and convert the variable to an integer.

# %% [markdown]
# #### 2. Bedrooms count:
#
# This function compares the number of bedrooms required by the user, which is explicitly asked, and the actual number of bedrooms of each Airbnb, called by the variable doc_bedroom. Resulting in a rate between 0 and 1, called bedroom_score.
#
# - The maximum bedroom_score you can have is 1, and it is reached when user_bedroom = doc_bedroom.
# - The minimum bedroom_score you can have is 0, and it is reached when doc_bedroom it's more than 3 bedrooms away from user_bedroom.
# - The intermediate values are given by areas around our variable of interest: user_bedrrom, giving more points to values closer and less to the farthest.

# %%
def bedroom_score(user_bedroom, doc_bedroom):
    if user_bedroom == doc_bedroom:
        bedroom_score = 1
    elif user_bedroom - 1 <= doc_bedroom <= user_bedroom + 1:
        bedroom_score = 0.75
    elif user_bedroom - 2 <= doc_bedroom <= user_bedroom + 2:
        bedroom_score = 0.5
    elif user_bedroom - 3 <= doc_bedroom <= user_bedroom + 3:
        bedroom_score = 0.25
    else:
        bedroom_score = 0
    return bedroom_score

# %% [markdown]
# In order to execute the previous function, we need to make some small modifications to the data as removing null values. In this case, the variable bedrooms_count contains numbers, and the string "Studio". A Studio is a small apartment which combines living room, bedroom, and kitchen into a single room, for that reason, we assume that when it says "Studio", it refers to a single bedroom. Ultimately we convert the variable to an integer.

# %%
# Remove null values
df = dataframe
df = df[pd.notnull(df["bedrooms_count"])]
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  average_rate_per_night bedrooms_count  \
# 0         16697         16698                      45              1
# 1          3186          3187                    1000              4
# 2          1553          1554                     150              3
# 3         15627         15628                    2000              4
# 4          2149          2150                      90              1
# 5          2414          2415                      38              1
# 6          3223          3224                     289              4
# 7          3601          3602                      37              1
# 8          5856          5857                      45              1
# 9          5986          5987                      36              1
# 10         6841          6842                      50              1
# 11        11525         11526                      75              2
# 12        12475         12476                     195              3
# 13          155           156                     768              2
# 14        18185         18186                     150              4
# 15         4039          4040                      40              1
# 16         7712          7713                      50              1
# 17        11918         11919                     250              3
# 18        12601         12602                      57              1
# 19        12785         12786                      25              1
# 20        13153         13154                      65              1
# 21        14732         14733                     200              2
# 22        14995         14996                     155              3
# 23        15836         15837                     100              3
# 24         2383          2384                      70              1
# 25         5741          5742                     950              4
# 26         8352          8353                     150              3
# 27        10273         10274                     139              2
# 28        10898         10899                      35              1
# 29        11180         11181                      25              1
# ..          ...           ...                     ...            ...
# 131        8741          8742                     139              2
# 132        8913          8914                      45              1
# 133        9148          9149                      18              1
# 134        9725          9726                      25              1
# 135       10169         10170                     200              1
# 136        1197          1198                      81              2
# 137       13061         13062                     400              3
# 138       14758         14759                      40              1
# 139       17578         17579                      65              2
# 140        2356          2357                      91              1
# 141        2682          2683                      50              1
# 142        2772          2773                     139              3
# 143        2909          2910                      99              1
# 144        4421          4422                      38              1
# 145        4523          4524                      46         Studio
# 146        7634          7635                    2000              2
# 147        7958          7959                     120              2
# 148        8760          8761                      40              1
# 149       15074         15075                      72              1
# 150       16422         16423                      65              1
# 151        1710          1711                      40              1
cool and comfortable bedroom apartment feel...  32.862116 -97.002643
# 21   This very unique charming home is one of the c...  32.794589 -96.789558
# 22   Beautiful remodeled 3 bedroom, 2 bath home jus...  33.192434 -96.642465
# 23   My place is close to major highways for easy a...  29.659373 -95.542636
# 24   Close to Major highway and toll\nAccess. Howar...  30.440253 -97.694393
# 25   My place is close to restaurants and dining an...  30.133220 -95.387730
# 26   My place is close to restaurants and dining in...  30.469885 -97.778484
# 27   We have promo rates until July 15! Key in your...  29.610547 -98.594406
# 28   Private room with shared guest bath in a 4BR h...  30.424197 -97.696490
# 29   Easy access to 410 and highway 151... About 15...  29.419302 -98.671484
# ..                                                 ...        ...        ...
# 131  We have promo rates until July 15! Key in your...  29.610386 -98.596384
# 132  Travellers, professionals, this is the place t...  29.518302 -98.726089
# 133  Inexpensive, simple alternative to a hotel/mot...  29.439991 -98.705548
# 134  My place is close to a variety of area restaur...  32.692764 -97.418444
# 135  Large house located 12 miles from downtown, ea...  30.060143 -97.827560
# 136  Enjoy your stay in East Texas with views of ro...  32.524937 -95.570954
# 137  My place is close to Katy mills mall and water...  29.757463 -95.809661
# 138  A short 10 minutes from DFW, only 20 minutes t...  32.820033 -97.092709
# 139  Very calm, quiet, and relaxing environment. Ga...  29.535162 -98.411669
# 140  Upscale, first floor, quiet one bedroom apartm...  30.487864 -97.654912
# 141  Large private room with sitting area and spaci...  29.574321 -98.450904
# 142  Nice home with open floor plan, large party ro...  29.521901 -98.447902
# 143  This elegant and modernly designed two-story l...  32.855156 -96.950938
# 144  One of three private rooms in a two story home...  32.930455 -96.965192
# 145  In the heart of the town of Natalia, comfy eff...  29.190306 -98.862756
# 146  Fully furnished home available for 2017 Super ...  29.718378 -95.671856
# 147  This quaint Cozy FTW Cottage has tons of chara...  32.768437 -97.403865
# 148  A short 10 minutes from DFW, only 20 minutes t...  32.820033 -97.092709
# 149  Private room available in Far North Dallas hom...  32.982801 -96.775461
# 150  Relax in this open space where art mixes with ...  29.473343 -98.525326
# 151  A short 10 minutes from DFW, only 20 minutes t...  32.818345 -97.092519
# 152  Private room and bathroom with room for one or...  32.627374 -97.373738
# 153  Lovely one story 2,300 sq. ft., 3 bedrooms 2 b...  30.660078 -96.267918
# 154  Our place is friendly, clean and cozy, with no...  30.460960 -97.583181
# 155  My cool comfortable3 bedroom home with plenty ...  32.987474 -96.876661
# 156  My place is close to Downtown, Easy access to ...  30.385996 -97.748745
# 157  Beautiful remodeled 3 bedroom, 2 bath home jus...  33.192434 -96.642465
# 158  A short 10 minutes from DFW, only 20 minutes t...  32.818345 -97.092519
# 159  This newly remodeled, stylishly decorated home...  29.564935 -98.369662
# 160  One of three private rooms in a two story home...  32.929012 -96.966895
#
#                                                  title  \
# 0                  Charm-Private Enrance-Good Location
# 1            Book for Superbowl! 4/5 bedroom, 3.5 bath
# 2    Beautiful home in Hurst. Easy access to Dallas/FW
# 3                         Superbowl Staycation Getaway
# 4                  Clean & Comfortable Room w/King Bed
# 5                       Private Room Near the Airports
# 6       Amazing House - Near Katy Mills and Water Park
# 7                                           Happy Home
# 8                  Bedroom near shopping peaceful area
# 9                           Private Room Near Airports
# 10         Large Quiet Private Room | Close to Airport
# 11    Charming Cottage close to the Alamo and Lackland
# 12                      S. Austin Great Location House
# 13                             SUPER BOWL WEEKEND 2017
# 14                       Spacious open home 2400 sqft.
# 15   Private Room | Quiet Space | Convenient to Air...
# 16                              Quiet Room Near Austin
# 17                 Luxury Apartment at La Cantera #106
# 18                            Houston Heights Homestay
# 19             Comfort/Style minutes from Downtown/TCU
# 20                   Cozy 1 bedroom/bathroom with pool
# 21                House 3 Blocks from Downtown, Uptown
# 22                  Remodeled - Near Downtown McKinney
# 23   Beautiful/Spacious house in convenient locatio...
# 24                                North Austin getaway
# 25                               Super Bowl Shangri La
# 26                   Inviting 3 BR house in NW Austin.
# 27    #1 2BR Ricchi Luxury Condo in San Antonio, Texas
# 28                    Cozy Private Room #1 Near Domain
# 29                 Single bedroom in a shared townhome
# ..                                                 ...
# 131   #2 2BR Ricchi Luxury Condo in San Antonio, Texas
# 132          Why stay at a hotel when you have a home?
# 133                 Private room and bath on far west!
# 134            Comfort/Style minutes from Downtown/TCU
# 135                             Room for Rent for SXSW
# 136                 The Cottage at Catalpa Corner Farm
# 137    New updated ranch home,acre yard with big trees
# 138  10 min to DFW airport, Six Flags, and AT&T Sta...
# 139                  Beautiful 2 bedroom/ 2 bath Condo
# 140                        Private luxury next to Dell
# 141        Large Quiet Private Room | Close to Airport
# 142  Open floor plan, party room, pool and comfy beds.
# 143                 Elegant/Modern Loft in Las Colinas
# 144                     Private Room Near the Airports
# 145                   Comfy, Cozy, Charming Efficiency
# 146     SUPERBOWL 2017 - Family Friendly Home For Rent
# 147     COZY FTW COTTAGE close to stockyard, Navy Base
# 148  10 min to DFW airport, Six Flags, and AT&T Sta...
# 149      Far North Dallas private room and bath w/pool
# 150                                        Casita Arte
# 151  10 min to DFW airport, Six Flags, and AT&T Sta...
# 152                      Cozy Room in South Fort Worth
# 153         Beautiful 3/2 home 5 miles from Texas A&M.
# 154   Clean, Quiet and Cozy - Two Private Rooms & Bath
# 155                                Home away from home
# 156              19 Foot Airstream Bambi International
# 157                 Remodeled - Near Downtown McKinney
# 158  10 min to DFW airport, Six Flags, and AT&T Sta...
# 159                 Renovated, 7 Mls From Randolph AFB
# 160                         Private Room Near Airports
#
#                                                    url          Similarity
# 0    https://www.airbnb.com/rooms/5183096?location=...  0.9933205307927605
# 1    https://www.airbnb.com/rooms/16056676?location...  0.9933205307927605
# 2    https://www.airbnb.com/rooms/14917951?location...  0.9933205307927604
# 3    https://www.airbnb.com/rooms/16854595?location...  0.9933205307927604
# 4    https://www.airbnb.com/rooms/14057644?location...  0.9933205307927604
# 5    https://www.airbnb.com/rooms/13602580?location...  0.9933205307927604
# 6    https://www.airbnb.com/rooms/15911826?location...  0.9933205307927604
# 7    https://www.airbnb.com/rooms/14782837?location...  0.9933205307927604
# 8    https://www.airbnb.com/rooms/12201369?location...  0.9933205307927604
# 9    https://www.airbnb.com/rooms/13604316?location...  0.9933205307927604
# 10   https://www.airbnb.com/rooms/19073250?location...  0.9933205307927604
# 11   https://www.airbnb.com/rooms/16873297?location...  0.9933205307927603
# 12   https://www.airbnb.com/rooms/10309872?location...  0.9933205307927603
# 13   https://www.airbnb.com/rooms/14991163?location...  0.9933205307927603
# 14   https://www.airbnb.com/rooms/19117708?location...  0.9933205307927603
# 15   https://www.airbnb.com/rooms/19038050?location...  0.9933205307927603
# 16   https://www.airbnb.com/rooms/18518056?location...  0.9933205307927603
# 17   https://www.airbnb.com/rooms/5036358?location=...  0.9933205307927602
# 18   https://www.airbnb.com/rooms/536807?location=B...  0.9933205307927602
# 19   https://www.airbnb.com/rooms/14770806?location...  0.9933205307927602
# 20   https://www.airbnb.com/rooms/7276294?location=...  0.9933205307927602
# 21   https://www.airbnb.com/rooms/12115172?location...  0.9933205307927602
# 22   https://www.airbnb.com/rooms/3522884?location=...  0.9933205307927602
# 23   https://www.airbnb.com/rooms/16334186?location...  0.9933205307927602
# 24   https://www.airbnb.com/rooms/18720660?location...  0.9933205307927602
# 25   https://www.airbnb.com/rooms/17000855?location...  0.9933205307927602
# 26   https://www.airbnb.com/rooms/14651757?location...  0.9933205307927602
# 27   https://www.airbnb.com/rooms/10783113?location...   0.986157019466115
# 28   https://www.airbnb.com/rooms/14163045?location...   0.986157019466115
# 29   https://www.airbnb.com/rooms/19205457?location...   0.986157019466115
# ..                                                 ...                 ...
# 131  https://www.airbnb.com/rooms/13207987?location...  0.9861570194661148
# 132  https://www.airbnb.com/rooms/1633767?location=...  0.9861570194661148
# 133  https://www.airbnb.com/rooms/16147758?location...  0.9861570194661148
# 134  https://www.airbnb.com/rooms/14770806?location...  0.9861570194661148
# 135  https://www.airbnb.com/rooms/2431585?location=...  0.9861570194661147
# 136  https://www.airbnb.com/rooms/16775972?location...  0.9861570194661147
# 137  https://www.airbnb.com/rooms/15501301?location...  0.9861570194661147
# 138  https://www.airbnb.com/rooms/7038625?location=...  0.9861570194661147
# 139  https://www.airbnb.com/rooms/17176922?location...  0.9861570194661147
# 140  https://www.airbnb.com/rooms/11714131?location...  0.9861570194661147
# 141  https://www.airbnb.com/rooms/19073250?location...  0.9861570194661147
# 142  https://www.airbnb.com/rooms/19442323?location...  0.9861570194661147
# 143  https://www.airbnb.com/rooms/9805537?location=...  0.9861570194661147
# 144  https://www.airbnb.com/rooms/13602580?location...  0.9861570194661147
# 145  https://www.airbnb.com/rooms/18288485?location...  0.9861570194661147
# 146  https://www.airbnb.com/rooms/16811771?location...  0.9861570194661147
# 147  https://www.airbnb.com/rooms/11778807?location...  0.9861570194661147
# 148  https://www.airbnb.com/rooms/7038625?location=...  0.9780833525297535
# 149  https://www.airbnb.com/rooms/19314043?location...  0.9780833525297534
# 150  https://www.airbnb.com/rooms/18025345?location...  0.9780833525297534
# 151  https://www.airbnb.com/rooms/18341099?location...  0.9780833525297534
# 152  https://www.airbnb.com/rooms/16911814?location...  0.9780833525297534
# 153  https://www.airbnb.com/rooms/14469997?location...  0.9780833525297534
# 154  https://www.airbnb.com/rooms/15813913?location...  0.9572512780500526
# 155  https://www.airbnb.com/rooms/16392671?location...  0.9572512780500526
# 156  https://www.airbnb.com/rooms/14530422?location...  0.9572512780500525
# 157  https://www.airbnb.com/rooms/3522884?location=...  0.9572512780500525
# 158  https://www.airbnb.com/rooms/18341099?location...  0.9572512780500523
# 159  https://www.airbnb.com/rooms/8404006?location=...  0.9572512780500523
# 160  https://www.airbnb.com/rooms/13604316?location...  0.8573739085673792
#
# [161 rows x 12 columns]

# %%
# # Replace Studio for 1
df['bedrooms_count'] = df['bedrooms_count'].replace('Studio', '1')

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  average_rate_per_night bedrooms_count  \
# 0         16697         16698                      45              1
# 1          3186          3187                    1000              4
# 2          1553          1554                     150              3
# 3         15627         15628                    2000              4
# 4          2149          2150                      90              1
# 5          2414          2415                      38              1
# 6          3223          3224                     289              4
# 7          3601          3602                      37              1
# 8          5856          5857                      45              1
# 9          5986          5987                      36              1
# 10         6841          6842                      50              1
# 11        11525         11526                      75              2
# 12        12475         12476                     195              3
# 13          155           156                     768              2
# 14        18185         18186                     150              4
# 15         4039          4040                      40              1
# 16         7712          7713                      50              1
# 17        11918         11919                     250              3
# 18        12601         12602                      57              1
# 19        12785         12786                      25              1
# 157  Beautiful remodeled 3 bedroom, 2 bath home jus...  33.192434 -96.642465
# 158  A short 10 minutes from DFW, only 20 minutes t...  32.818345 -97.092519
# 159  This newly remodeled, stylishly decorated home...  29.564935 -98.369662
# 160  One of three private rooms in a two story home...  32.929012 -96.966895
#
#                                                  title  \
# 0                  Charm-Private Enrance-Good Location
# 1            Book for Superbowl! 4/5 bedroom, 3.5 bath
# 2    Beautiful home in Hurst. Easy access to Dallas/FW
# 3                         Superbowl Staycation Getaway
# 4                  Clean & Comfortable Room w/King Bed
# 5                       Private Room Near the Airports
# 6       Amazing House - Near Katy Mills and Water Park
# 7                                           Happy Home
# 8                  Bedroom near shopping peaceful area
# 9                           Private Room Near Airports
# 10         Large Quiet Private Room | Close to Airport
# 11    Charming Cottage close to the Alamo and Lackland
# 12                      S. Austin Great Location House
# 13                             SUPER BOWL WEEKEND 2017
# 14                       Spacious open home 2400 sqft.
# 15   Private Room | Quiet Space | Convenient to Air...
# 16                              Quiet Room Near Austin
# 17                 Luxury Apartment at La Cantera #106
# 18                            Houston Heights Homestay
# 19             Comfort/Style minutes from Downtown/TCU
# 20                   Cozy 1 bedroom/bathroom with pool
# 21                House 3 Blocks from Downtown, Uptown
# 22                  Remodeled - Near Downtown McKinney
# 23   Beautiful/Spacious house in convenient locatio...
# 24                                North Austin getaway
# 25                               Super Bowl Shangri La
# 26                   Inviting 3 BR house in NW Austin.
# 27    #1 2BR Ricchi Luxury Condo in San Antonio, Texas
# 28                    Cozy Private Room #1 Near Domain
# 29                 Single bedroom in a shared townhome
# ..                                                 ...
# 131   #2 2BR Ricchi Luxury Condo in San Antonio, Texas
# 132          Why stay at a hotel when you have a home?
# 133                 Private room and bath on far west!
# 134            Comfort/Style minutes from Downtown/TCU
# 135                             Room for Rent for SXSW
# 136                 The Cottage at Catalpa Corner Farm
# 137    New updated ranch home,acre yard with big trees
# 138  10 min to DFW airport, Six Flags, and AT&T Sta...
# 139                  Beautiful 2 bedroom/ 2 bath Condo
# 140                        Private luxury next to Dell
# 141        Large Quiet Private Room | Close to Airport
# 142  Open floor plan, party room, pool and comfy beds.
# 143                 Elegant/Modern Loft in Las Colinas
# 144                     Private Room Near the Airports
# 145                   Comfy, Cozy, Charming Efficiency
# 146     SUPERBOWL 2017 - Family Friendly Home For Rent
# 147     COZY FTW COTTAGE close to stockyard, Navy Base
# 148  10 min to DFW airport, Six Flags, and AT&T Sta...
# 149      Far North Dallas private room and bath w/pool
# 150                                        Casita Arte
# 151  10 min to DFW airport, Six Flags, and AT&T Sta...
# 152                      Cozy Room in South Fort Worth
# 153         Beautiful 3/2 home 5 miles from Texas A&M.
# 154   Clean, Quiet and Cozy - Two Private Rooms & Bath
# 155                                Home away from home
# 156              19 Foot Airstream Bambi International
# 157                 Remodeled - Near Downtown McKinney
# 158  10 min to DFW airport, Six Flags, and AT&T Sta...
# 159                 Renovated, 7 Mls From Randolph AFB
# 160                         Private Room Near Airports
#
#                                                    url          Similarity
# 0    https://www.airbnb.com/rooms/5183096?location=...  0.9933205307927605
# 1    https://www.airbnb.com/rooms/16056676?location...  0.9933205307927605
# 2    https://www.airbnb.com/rooms/14917951?location...  0.9933205307927604
# 3    https://www.airbnb.com/rooms/16854595?location...  0.9933205307927604
# 4    https://www.airbnb.com/rooms/14057644?location...  0.9933205307927604
# 5    https://www.airbnb.com/rooms/13602580?location...  0.9933205307927604
# 6    https://www.airbnb.com/rooms/15911826?location...  0.9933205307927604
# 7    https://www.airbnb.com/rooms/14782837?location...  0.9933205307927604
# 8    https://www.airbnb.com/rooms/12201369?location...  0.9933205307927604
# 9    https://www.airbnb.com/rooms/13604316?location...  0.9933205307927604
# 10   https://www.airbnb.com/rooms/19073250?location...  0.9933205307927604
# 11   https://www.airbnb.com/rooms/16873297?location...  0.9933205307927603
# 12   https://www.airbnb.com/rooms/10309872?location...  0.9933205307927603
# 13   https://www.airbnb.com/rooms/14991163?location...  0.9933205307927603
# 14   https://www.airbnb.com/rooms/19117708?location...  0.9933205307927603
# 15   https://www.airbnb.com/rooms/19038050?location...  0.9933205307927603
# 16   https://www.airbnb.com/rooms/18518056?location...  0.9933205307927603
# 17   https://www.airbnb.com/rooms/5036358?location=...  0.9933205307927602
# 18   https://www.airbnb.com/rooms/536807?location=B...  0.9933205307927602
# 19   https://www.airbnb.com/rooms/14770806?location...  0.9933205307927602
# 20   https://www.airbnb.com/rooms/7276294?location=...  0.9933205307927602
# 21   https://www.airbnb.com/rooms/12115172?location...  0.9933205307927602
# 22   https://www.airbnb.com/rooms/3522884?location=...  0.9933205307927602
# 23   https://www.airbnb.com/rooms/16334186?location...  0.9933205307927602
# 24   https://www.airbnb.com/rooms/18720660?location...  0.9933205307927602
# 25   https://www.airbnb.com/rooms/17000855?location...  0.9933205307927602
# 26   https://www.airbnb.com/rooms/14651757?location...  0.9933205307927602
# 27   https://www.airbnb.com/rooms/10783113?location...   0.986157019466115
# 28   https://www.airbnb.com/rooms/14163045?location...   0.986157019466115
# 29   https://www.airbnb.com/rooms/19205457?location...   0.986157019466115
# ..                                                 ...                 ...
# 131  https://www.airbnb.com/rooms/13207987?location...  0.9861570194661148
# 132  https://www.airbnb.com/rooms/1633767?location=...  0.9861570194661148
# 133  https://www.airbnb.com/rooms/16147758?location...  0.9861570194661148
# 134  https://www.airbnb.com/rooms/14770806?location...  0.9861570194661148
# 135  https://www.airbnb.com/rooms/2431585?location=...  0.9861570194661147
# 136  https://www.airbnb.com/rooms/16775972?location...  0.9861570194661147
# 137  https://www.airbnb.com/rooms/15501301?location...  0.9861570194661147
# 138  https://www.airbnb.com/rooms/7038625?location=...  0.9861570194661147
# 139  https://www.airbnb.com/rooms/17176922?location...  0.9861570194661147
# 140  https://www.airbnb.com/rooms/11714131?location...  0.9861570194661147
# 141  https://www.airbnb.com/rooms/19073250?location...  0.9861570194661147
# 142  https://www.airbnb.com/rooms/19442323?location...  0.9861570194661147
# 143  https://www.airbnb.com/rooms/9805537?location=...  0.9861570194661147
# 144  https://www.airbnb.com/rooms/13602580?location...  0.9861570194661147
# 145  https://www.airbnb.com/rooms/18288485?location...  0.9861570194661147
# 146  https://www.airbnb.com/rooms/16811771?location...  0.9861570194661147
# 147  https://www.airbnb.com/rooms/11778807?location...  0.9861570194661147
# 148  https://www.airbnb.com/rooms/7038625?location=...  0.9780833525297535
# 149  https://www.airbnb.com/rooms/19314043?location...  0.9780833525297534
# 150  https://www.airbnb.com/rooms/18025345?location...  0.9780833525297534
# 151  https://www.airbnb.com/rooms/18341099?location...  0.9780833525297534
# 152  https://www.airbnb.com/rooms/16911814?location...  0.9780833525297534
# 153  https://www.airbnb.com/rooms/14469997?location...  0.9780833525297534
# 154  https://www.airbnb.com/rooms/15813913?location...  0.9572512780500526
# 155  https://www.airbnb.com/rooms/16392671?location...  0.9572512780500526
# 156  https://www.airbnb.com/rooms/14530422?location...  0.9572512780500525
# 157  https://www.airbnb.com/rooms/3522884?location=...  0.9572512780500525
# 158  https://www.airbnb.com/rooms/18341099?location...  0.9572512780500523
# 159  https://www.airbnb.com/rooms/8404006?location=...  0.9572512780500523
# 160  https://www.airbnb.com/rooms/13604316?location...  0.8573739085673792
#
# [161 rows x 12 columns]

# %%
# # Convert to integer
df['bedrooms_count'] = df['bedrooms_count'].astype(int)

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  average_rate_per_night  bedrooms_count  \
# 0         16697         16698                      45               1
# 1          3186          3187                    1000               4
# 2          1553          1554                     150               3
# 3         15627         15628                    2000               4
# 4          2149          2150                      90               1
# 5          2414          2415                      38               1
# 6          3223          3224                     289               4
# 7          3601          3602                      37               1
# 8          5856          5857                      45               1
# 9          5986          5987                      36               1
# 10         6841          6842                      50               1
# 11        11525         11526                      75               2
# 12        12475         12476                     195               3
# 13          155           156                     768               2
# 14        18185         18186                     150               4
# 15         4039          4040                      40               1
# 16         7712          7713                      50               1
# 17        11918         11919                     250               3
# 18        12601         12602                      57               1
# 19        12785         12786                      25               1
# 20        13153         13154                      65               1
# 21        14732         14733                     200               2
# 22        14995         14996                     155               3
# 23        15836         15837                     100               3
# 24         2383          2384                      70               1
# 25         5741          5742                     950               4
# 26         8352          8353                     150               3
# 27        10273         10274                     139               2
# 28        10898         10899                      35               1
# 29        11180         11181                      25               1
# ..          ...           ...                     ...             ...
# 131        8741          8742                     139               2
# 132        8913          8914                      45               1
# 133        9148          9149                      18               1
# 134        9725          9726                      25               1
# 135       10169         10170                     200               1
# 136        1197          1198                      81               2
# 137       13061         13062                     400               3
# 138       14758         14759                      40               1
# 139       17578         17579                      65               2
# 140        2356          2357                      91               1
# 141        2682          2683                      50               1
# 142        2772          2773                     139               3
# 143        2909          2910                      99               1
# 144        4421          4422                      38               1
# 145        4523          4524                      46               1
# 146        7634          7635                    2000               2
# 147        7958          7959                     120               2
# 148        8760          8761                      40               1
# 149       15074         15075                      72               1
# 150       16422         16423                      65               1
# 151        1710          1711                      40               1
# 152         450           451                      30               1
# 153        8584          8585                     750               3
# 154        2276          2277                     100               1
# 155        7108          7109                      50               1
# 156        3182          3183                      75               1
# 157        9318          9319                     155               3
# 158       12098         12099                      40               1
# 159        2913          2914                     185               2
# 160        3549          3550                      36               1
#
#                 city date_of_listing  \
# 0        San Antonio      March 2014
# 1            Houston   November 2016
# 2              Hurst  September 2016
# 3         Sugar Land    January 2017
# 4     Corpus Christi       July 2016
# 5             Irving       June 2016
# 6               Katy    January 2014
# 7         Fort Worth     August 2016
# 8           Converse      March 2016
# 9             Irving       June 2016
# 10       San Antonio       June 2016
# 11       San Antonio    January 2017
# 12            Austin    January 2016
# 13          Richmond  September 2016
# 14            Dallas       June 2017
# 15       San Antonio       June 2016
# 16        Cedar Park     August 2014
# 17       San Antonio    January 2015
# 18           Houston      March 2012
# 19          Benbrook     August 2016
# 20            Irving       July 2015
# 21            Dallas      April 2013
# 22          McKinney       July 2014
# 23           Houston       June 2016
# 24            Austin      April 2016
# 25            Spring    January 2017
# 26            Austin      March 2015
# 27       San Antonio  September 2015
# 28            Austin       July 2016
# 29       San Antonio       June 2017
# ..               ...             ...
# 131      San Antonio  September 2015
A short 10 minutes from DFW, only 20 minutes t...  32.820033 -97.092709
# 139  Very calm, quiet, and relaxing environment. Ga...  29.535162 -98.411669
# 140  Upscale, first floor, quiet one bedroom apartm...  30.487864 -97.654912
# 141  Large private room with sitting area and spaci...  29.574321 -98.450904
# 142  Nice home with open floor plan, large party ro...  29.521901 -98.447902
# 143  This elegant and modernly designed two-story l...  32.855156 -96.950938
# 144  One of three private rooms in a two story home...  32.930455 -96.965192
# 145  In the heart of the town of Natalia, comfy eff...  29.190306 -98.862756
# 146  Fully furnished home available for 2017 Super ...  29.718378 -95.671856
# 147  This quaint Cozy FTW Cottage has tons of chara...  32.768437 -97.403865
# 148  A short 10 minutes from DFW, only 20 minutes t...  32.820033 -97.092709
# 149  Private room available in Far North Dallas hom...  32.982801 -96.775461
# 150  Relax in this open space where art mixes with ...  29.473343 -98.525326
# 151  A short 10 minutes from DFW, only 20 minutes t...  32.818345 -97.092519
# 152  Private room and bathroom with room for one or...  32.627374 -97.373738
# 153  Lovely one story 2,300 sq. ft., 3 bedrooms 2 b...  30.660078 -96.267918
# 154  Our place is friendly, clean and cozy, with no...  30.460960 -97.583181
# 155  My cool comfortable3 bedroom home with plenty ...  32.987474 -96.876661
# 156  My place is close to Downtown, Easy access to ...  30.385996 -97.748745
# 157  Beautiful remodeled 3 bedroom, 2 bath home jus...  33.192434 -96.642465
# 158  A short 10 minutes from DFW, only 20 minutes t...  32.818345 -97.092519
# 159  This newly remodeled, stylishly decorated home...  29.564935 -98.369662
# 160  One of three private rooms in a two story home...  32.929012 -96.966895
#
#                                                  title  \
# 0                  Charm-Private Enrance-Good Location
# 1            Book for Superbowl! 4/5 bedroom, 3.5 bath
# 2    Beautiful home in Hurst. Easy access to Dallas/FW
# 3                         Superbowl Staycation Getaway
# 4                  Clean & Comfortable Room w/King Bed
# 5                       Private Room Near the Airports
# 6       Amazing House - Near Katy Mills and Water Park
# 7                                           Happy Home
# 8                  Bedroom near shopping peaceful area
# 9                           Private Room Near Airports
# 10         Large Quiet Private Room | Close to Airport
# 11    Charming Cottage close to the Alamo and Lackland
# 12                      S. Austin Great Location House
# 13                             SUPER BOWL WEEKEND 2017
# 14                       Spacious open home 2400 sqft.
# 15   Private Room | Quiet Space | Convenient to Air...
# 16                              Quiet Room Near Austin
# 17                 Luxury Apartment at La Cantera #106
# 18                            Houston Heights Homestay
# 19             Comfort/Style minutes from Downtown/TCU
# 20                   Cozy 1 bedroom/bathroom with pool
# 21                House 3 Blocks from Downtown, Uptown
# 22                  Remodeled - Near Downtown McKinney
# 23   Beautiful/Spacious house in convenient locatio...
# 24                                North Austin getaway
# 25                               Super Bowl Shangri La
# 26                   Inviting 3 BR house in NW Austin.
# 27    #1 2BR Ricchi Luxury Condo in San Antonio, Texas
# 28                    Cozy Private Room #1 Near Domain
# 29                 Single bedroom in a shared townhome
# ..                                                 ...
# 131   #2 2BR Ricchi Luxury Condo in San Antonio, Texas
# 132          Why stay at a hotel when you have a home?
# 133                 Private room and bath on far west!
# 134            Comfort/Style minutes from Downtown/TCU
# 135                             Room for Rent for SXSW
# 136                 The Cottage at Catalpa Corner Farm
# 137    New updated ranch home,acre yard with big trees
# 138  10 min to DFW airport, Six Flags, and AT&T Sta...
# 139                  Beautiful 2 bedroom/ 2 bath Condo
# 140                        Private luxury next to Dell
# 141        Large Quiet Private Room | Close to Airport
# 142  Open floor plan, party room, pool and comfy beds.
# 143                 Elegant/Modern Loft in Las Colinas
# 144                     Private Room Near the Airports
# 145                   Comfy, Cozy, Charming Efficiency
# 146     SUPERBOWL 2017 - Family Friendly Home For Rent
# 147     COZY FTW COTTAGE close to stockyard, Navy Base
# 148  10 min to DFW airport, Six Flags, and AT&T Sta...
# 149      Far North Dallas private room and bath w/pool
# 150                                        Casita Arte
# 151  10 min to DFW airport, Six Flags, and AT&T Sta...
# 152                      Cozy Room in South Fort Worth
# 153         Beautiful 3/2 home 5 miles from Texas A&M.
# 154   Clean, Quiet and Cozy - Two Private Rooms & Bath
# 155                                Home away from home
# 156              19 Foot Airstream Bambi International
# 157                 Remodeled - Near Downtown McKinney
# 158  10 min to DFW airport, Six Flags, and AT&T Sta...
# 159                 Renovated, 7 Mls From Randolph AFB
# 160                         Private Room Near Airports
#
#                                                    url          Similarity
# 0    https://www.airbnb.com/rooms/5183096?location=...  0.9933205307927605
# 1    https://www.airbnb.com/rooms/16056676?location...  0.9933205307927605
# 2    https://www.airbnb.com/rooms/14917951?location...  0.9933205307927604
# 3    https://www.airbnb.com/rooms/16854595?location...  0.9933205307927604
# 4    https://www.airbnb.com/rooms/14057644?location...  0.9933205307927604
# 5    https://www.airbnb.com/rooms/13602580?location...  0.9933205307927604
# 6    https://www.airbnb.com/rooms/15911826?location...  0.9933205307927604
# 7    https://www.airbnb.com/rooms/14782837?location...  0.9933205307927604
# 8    https://www.airbnb.com/rooms/12201369?location...  0.9933205307927604
# 9    https://www.airbnb.com/rooms/13604316?location...  0.9933205307927604
# 10   https://www.airbnb.com/rooms/19073250?location...  0.9933205307927604
# 11   https://www.airbnb.com/rooms/16873297?location...  0.9933205307927603
# 12   https://www.airbnb.com/rooms/10309872?location...  0.9933205307927603
# 13   https://www.airbnb.com/rooms/14991163?location...  0.9933205307927603
# 14   https://www.airbnb.com/rooms/19117708?location...  0.9933205307927603
# 15   https://www.airbnb.com/rooms/19038050?location...  0.9933205307927603
# 16   https://www.airbnb.com/rooms/18518056?location...  0.9933205307927603
# 17   https://www.airbnb.com/rooms/5036358?location=...  0.9933205307927602
# 18   https://www.airbnb.com/rooms/536807?location=B...  0.9933205307927602
# 19   https://www.airbnb.com/rooms/14770806?location...  0.9933205307927602
# 20   https://www.airbnb.com/rooms/7276294?location=...  0.9933205307927602
# 21   https://www.airbnb.com/rooms/12115172?location...  0.9933205307927602
# 22   https://www.airbnb.com/rooms/3522884?location=...  0.9933205307927602
# 23   https://www.airbnb.com/rooms/16334186?location...  0.9933205307927602
# 24   https://www.airbnb.com/rooms/18720660?location...  0.9933205307927602
# 25   https://www.airbnb.com/rooms/17000855?location...  0.9933205307927602
# 26   https://www.airbnb.com/rooms/14651757?location...  0.9933205307927602
# 27   https://www.airbnb.com/rooms/10783113?location...   0.986157019466115
# 28   https://www.airbnb.com/rooms/14163045?location...   0.986157019466115
# 29   https://www.airbnb.com/rooms/19205457?location...   0.986157019466115
# ..                                                 ...                 ...
# 131  https://www.airbnb.com/rooms/13207987?location...  0.9861570194661148
# 132  https://www.airbnb.com/rooms/1633767?location=...  0.9861570194661148
# 133  https://www.airbnb.com/rooms/16147758?location...  0.9861570194661148
# 134  https://www.airbnb.com/rooms/14770806?location...  0.9861570194661148
# 135  https://www.airbnb.com/rooms/2431585?location=...  0.9861570194661147
# 136  https://www.airbnb.com/rooms/16775972?location...  0.9861570194661147
# 137  https://www.airbnb.com/rooms/15501301?location...  0.9861570194661147
# 138  https://www.airbnb.com/rooms/7038625?location=...  0.9861570194661147
# 139  https://www.airbnb.com/rooms/17176922?location...  0.9861570194661147
# 140  https://www.airbnb.com/rooms/11714131?location...  0.9861570194661147
# 141  https://www.airbnb.com/rooms/19073250?location...  0.9861570194661147
# 142  https://www.airbnb.com/rooms/19442323?location...  0.9861570194661147
# 143  https://www.airbnb.com/rooms/9805537?location=...  0.9861570194661147
# 144  https://www.airbnb.com/rooms/13602580?location...  0.9861570194661147
# 145  https://www.airbnb.com/rooms/18288485?location...  0.9861570194661147
# 146  https://www.airbnb.com/rooms/16811771?location...  0.9861570194661147
# 147  https://www.airbnb.com/rooms/11778807?location...  0.9861570194661147
# 148  https://www.airbnb.com/rooms/7038625?location=...  0.9780833525297535
# 149  https://www.airbnb.com/rooms/19314043?location...  0.9780833525297534
# 150  https://www.airbnb.com/rooms/18025345?location...  0.9780833525297534
# 151  https://www.airbnb.com/rooms/18341099?location...  0.9780833525297534
# 152  https://www.airbnb.com/rooms/16911814?location...  0.9780833525297534
# 153  https://www.airbnb.com/rooms/14469997?location...  0.9780833525297534
# 154  https://www.airbnb.com/rooms/15813913?location...  0.9572512780500526
# 155  https://www.airbnb.com/rooms/16392671?location...  0.9572512780500526
# 156  https://www.airbnb.com/rooms/14530422?location...  0.9572512780500525
# 157  https://www.airbnb.com/rooms/3522884?location=...  0.9572512780500525
# 158  https://www.airbnb.com/rooms/18341099?location...  0.9572512780500523
# 159  https://www.airbnb.com/rooms/8404006?location=...  0.9572512780500523
# 160  https://www.airbnb.com/rooms/13604316?location...  0.8573739085673792
#
# [161 rows x 12 columns]

# %% [markdown]
# #### 3. City:
#
# This function compares the city preference specified by the user, and the actual city of each Airbnb, called by the variable doc_city. Resulting in a binary rate that takes the value 1 when user_city = doc_city, and 0 otherwise.

# %%
pip install geopy # this is required it should be run outside
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install geopy # this is required it should be run outside
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
import geopy.distance

# %%
def city_score(user_city_latitude, user_city_longitude, doc_city_latitude, doc_city_longitude):
    coords_1 = (user_city_latitude, user_city_longitude) #we have to found a way to get the coordinates from the name of the city
    coords_2 = (doc_city_latitude, doc_city_longitude)
    distance = geopy.distance.vincenty(coords_1, coords_2).km
    if 0 < distance < 5:
        city_score = 1
    elif 5 <= distance <= 10:
        city_score = 0.50
    elif 10 <= distance <= 20:
        city_score = 0.25
    else:
        city_score = 0.10
    return city_score

# %% [markdown]
# #### 4. Date of listing:
#
# In this case, the score assigned to each Airbnb, is not given by the information provided by the user.
# We assume that an older date of listing means that the owner of the Airbnb is a more experienced one and therefore is a better option for the user. In this way, we give a lower score to the newer Airbnb and a higher one to the older ones. The date_score variable also belongs to the interval between 0 and 1. The chosen method is the follower: we calculate the quantiles of the dates' distribution and we assign a score based on the date position: the oldest dates'll be near the first quantile, the yongest dates 'll be near the third quantile. This method always guarantees a higher score on the oldest dates.

# %%
def date_score(doc_date_of_listing):
    df.date_of_listing = pd.to_datetime(df.date_of_listing)
    first_quantile=df.date_of_listing.quantile(0.25)
    median = df.date_of_listing.quantile(0.5)
    third_quantile = df.date_of_listing.quantile(0.75)
    
    if doc_date_of_listing <= first_quantile:
        date_score = 1
    elif first_quantile < doc_date_of_listing <= median:
        date_score = 0.75
    elif median < doc_date_of_listing < third_quantile:
        date_score = 0.5
    elif doc_date_of_listing >= third_quantile:
        date_score = 0.25
    
    return date_score

# %% [markdown]
# ####  Final Score
# To finish, we will define the function that calculates the final score for each Airbnb, doing a weighted average of our four previously calculated scores. As we do not find any relevant reason to assign more weight to one variable than to another, we weight each sub score, as 25% of the total.
#
# Again we have a result that oscillates between 0 and 1, where 1 represents a greater similarity of Airbnb with the preferences of the user.

# %%
def final_score(rate_score, bedroom_score, city_score, date_score):
    return 0.25*rate_score + 0.25*bedroom_score + 0.25*city_score + 0.25*date_score

# %% [markdown]
# ### EXAMPLE

# %% [markdown]
# So we already have result from conjuctive query lets apply it on dataframe. Let me referesh the memory how it looks

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  average_rate_per_night  bedrooms_count  \
# 0         16697         16698                      45               1
# 1          3186          3187                    1000               4
# 2          1553          1554                     150               3
# 3         15627         15628                    2000               4
# 4          2149          2150                      90               1
# 5          2414          2415                      38               1
# 6          3223          3224                     289               4
# 7          3601          3602                      37               1
# 8          5856          5857                      45               1
# 9          5986          5987                      36               1
# 10         6841          6842                      50               1
# 11        11525         11526                      75               2
# 12        12475         12476                     195               3
# 13          155           156                     768               2
# 14        18185         18186                     150               4
# 15         4039          4040                      40               1
# 16         7712          7713                      50               1
# 17        11918         11919                     250               3
# 18        12601         12602                      57               1
# 19        12785         12786                      25               1
# 20        13153         13154                      65               1
# 21        14732         14733                     200               2
# 22        14995         14996                     155               3
# 23        15836         15837                     100               3
# 24         2383          2384                      70               1
# 25         5741          5742                     950               4
# 26         8352          8353                     150               3
# 27        10273         10274                     139               2
# 28        10898         10899                      35               1
# 29        11180         11181                      25               1
# ..          ...           ...                     ...             ...
# 131        8741          8742                     139               2
# 132        8913          8914                      45               1
# 133        9148          9149                      18               1
# 134        9725          9726                      25               1
# 135       10169         10170                     200               1
# 136        1197          1198                      81               2
# 137       13061         13062                     400               3
# 138       14758         14759                      40               1
# 139       17578         17579                      65               2
# 140        2356          2357                      91               1
# 141        2682          2683                      50               1
# 142        2772          2773                     139               3
# 143        2909          2910                      99               1
# 144        4421          4422                      38               1
# 145        4523          4524                      46               1
# 146        7634          7635                    2000               2
# 147        7958          7959                     120               2
# 148        8760          8761                      40               1
# 149       15074         15075                      72               1
# 150       16422         16423                      65               1
# 151        1710          1711                      40               1
# 152         450           451                      30               1
# 153        8584          8585                     750               3
# 154        2276          2277                     100               1
# 155        7108          7109                      50               1
# 156        3182          3183                      75               1
# 157        9318          9319                     155               3
# 158       12098         12099                      40               1
# 159        2913          2914                     185               2
# 160        3549          3550                      36               1
#
#                 city date_of_listing  \
# 0        San Antonio      March 2014
# 1            Houston   November 2016
# 2              Hurst  September 2016
# 3         Sugar Land    January 2017
# 4     Corpus Christi       July 2016
# 5             Irving       June 2016
# 6               Katy    January 2014
# 7         Fort Worth     August 2016
# 8           Converse      March 2016
# 9             Irving       June 2016
# 10       San Antonio       June 2016
# 11       San Antonio    January 2017
# 12            Austin    January 2016
# 13          Richmond  September 2016
# 14            Dallas       June 2017
# 15       San Antonio       June 2016
# 16        Cedar Park     August 2014
# 17       San Antonio    January 2015
# 18           Houston      March 2012
# 19          Benbrook     August 2016
# 20            Irving       July 2015
# 21            Dallas      April 2013
# 22          McKinney       July 2014
# 23           Houston       June 2016
# 24            Austin      April 2016
# 25            Spring    January 2017
# 26            Austin      March 2015
# 27       San Antonio  September 2015
# 28            Austin       July 2016
# 27   https://www.airbnb.com/rooms/10783113?location...   0.986157019466115
# 28   https://www.airbnb.com/rooms/14163045?location...   0.986157019466115
# 29   https://www.airbnb.com/rooms/19205457?location...   0.986157019466115
# ..                                                 ...                 ...
# 131  https://www.airbnb.com/rooms/13207987?location...  0.9861570194661148
# 132  https://www.airbnb.com/rooms/1633767?location=...  0.9861570194661148
# 133  https://www.airbnb.com/rooms/16147758?location...  0.9861570194661148
# 134  https://www.airbnb.com/rooms/14770806?location...  0.9861570194661148
# 135  https://www.airbnb.com/rooms/2431585?location=...  0.9861570194661147
# 136  https://www.airbnb.com/rooms/16775972?location...  0.9861570194661147
# 137  https://www.airbnb.com/rooms/15501301?location...  0.9861570194661147
# 138  https://www.airbnb.com/rooms/7038625?location=...  0.9861570194661147
# 139  https://www.airbnb.com/rooms/17176922?location...  0.9861570194661147
# 140  https://www.airbnb.com/rooms/11714131?location...  0.9861570194661147
# 141  https://www.airbnb.com/rooms/19073250?location...  0.9861570194661147
# 142  https://www.airbnb.com/rooms/19442323?location...  0.9861570194661147
# 143  https://www.airbnb.com/rooms/9805537?location=...  0.9861570194661147
# 144  https://www.airbnb.com/rooms/13602580?location...  0.9861570194661147
# 145  https://www.airbnb.com/rooms/18288485?location...  0.9861570194661147
# 146  https://www.airbnb.com/rooms/16811771?location...  0.9861570194661147
# 147  https://www.airbnb.com/rooms/11778807?location...  0.9861570194661147
# 148  https://www.airbnb.com/rooms/7038625?location=...  0.9780833525297535
# 149  https://www.airbnb.com/rooms/19314043?location...  0.9780833525297534
# 150  https://www.airbnb.com/rooms/18025345?location...  0.9780833525297534
# 151  https://www.airbnb.com/rooms/18341099?location...  0.9780833525297534
# 152  https://www.airbnb.com/rooms/16911814?location...  0.9780833525297534
# 153  https://www.airbnb.com/rooms/14469997?location...  0.9780833525297534
# 154  https://www.airbnb.com/rooms/15813913?location...  0.9572512780500526
# 155  https://www.airbnb.com/rooms/16392671?location...  0.9572512780500526
# 156  https://www.airbnb.com/rooms/14530422?location...  0.9572512780500525
# 157  https://www.airbnb.com/rooms/3522884?location=...  0.9572512780500525
# 158  https://www.airbnb.com/rooms/18341099?location...  0.9572512780500523
# 159  https://www.airbnb.com/rooms/8404006?location=...  0.9572512780500523
# 160  https://www.airbnb.com/rooms/13604316?location...  0.8573739085673792
#
# [161 rows x 12 columns]

# %% [markdown]
# Lets gather information about user's preferences

# %%
user_rate = int(input("How much is the ideal rate you would pay per night? "))
user_bedroom = int(input("How many bedrooms do you need? "))
user_city = input("In wich city do you prefer to stay? ")
# Out:
# How much is the ideal rate you would pay per night? 56
# How many bedrooms do you need? 2
# In wich city do you prefer to stay? Dallas

# %%
# create a new column with empty values
df["New Score"] = ""

# %% [markdown]
# user entered the dellas and we

# %%
# fill that empty space with the result of computing the final score
for i in range(len(df)):
    rs = rate_score(user_rate, df["average_rate_per_night"][i])
    bs = bedroom_score(user_bedroom, df["bedrooms_count"][i])
    cs = city_score(user_city, df["city"][i])
    ds = date_score(doc_date_of_listing, df["date_of_listing"][i])
    fs = final_score(rs, bs, cs, ds)
    df["New Score"][i] = fs
